# %% [markdown]
# Try to wrangle the text file into a list of sentences.

# %%
Before you run this you need to create a table in a postgress database 

create table embeddings (ID SERIAL PRIMARY KEY,                           
                         author text, line int, book text, embedding bytea, snippit text, model text);

# %%
import os 
import psycopg2 
import IProgress 
import pickle 
import numpy
from nltk.tokenize import sent_tokenize
from sentence_transformers import SentenceTransformer

# %%
#these are simple convenience functions that the data prep uses. 

def get_and_tokenise(play):
    tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    fp = open("shakespeare-db/"+play)
    data = fp.read()
    tokens = sent_tokenize(data)
    new_tokens = [n.split('\n', 1)[1] for n in tokens if len(n.split('\n',1)) > 1]
    next_tokens = [u for u in new_tokens]
    return next_tokens

def embed(tokens, model):
    #do the embeddings 
    sentences = tokens
    model = SentenceTransformer('sentence-transformers/'+model)
    embeddings = model.encode(sentences,show_progress_bar=True)
    return embeddings

# %% [markdown]
# The code below is the main function that imports the model and then creates the embeddings before stuffing them into a data base for reuse. Each row in the database will be an embedding with metadata about what it embeds and the model used.

# %%
model = "all-MiniLM-L12-v1"
plays = os.listdir("shakespeare-db")
conn = psycopg2.connect("dbname=postgres user=postgres password=postgres")
conn.autocommit = True
cur = conn.cursor()
        
for play in plays: 
    print (play)
    count = 0;
    tokens = get_and_tokenise(play)
    embeddings = embed(tokens, model)

    for this_token, this_embed in zip(tokens, embeddings):
        cur.execute('INSERT into embeddings (author,book,line, embedding, snippit,model) \
                    values (%s,%s,%s,%s,%s,%s) ',("Shakespear",play,count,pickle.dumps(this_embed),this_token,model))
        count=count+1
    print ("lines embedded =", count)
# Out:
# As You Like It.txt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a485b026d8d8> in <module>
#       8     print (play)
#       9     count = 0;
# ---> 10     tokens = get_and_tokenise(play)
#      11     embeddings = embed(tokens, model)
#      12
#
# NameError: name 'get_and_tokenise' is not defined

# %% [markdown]
# The database now has all the embeddings in it so we can start to use them.
# Retrive all the Shakespeare ones in the next cell.

# %%
model = "all-MiniLM-L12-v1"
conn = psycopg2.connect("dbname=postgres user=postgres password=postgres")
cur = conn.cursor()
cur.execute('SELECT id, book,line,embedding from embeddings where embeddings.author=%s',("Shakespear",))
embeddings = cur.fetchall()

# %%
embeddings
# Out:
# [(35098, 'As You Like It.txt', 140, <memory at 0x7febdef74dc0>),
#  (35099, 'As You Like It.txt', 141, <memory at 0x7febdef74e80>),
#  (35100, 'As You Like It.txt', 142, <memory at 0x7febdef74f40>),
#  (35101, 'As You Like It.txt', 143, <memory at 0x7febdef74c40>),
#  (35102, 'As You Like It.txt', 144, <memory at 0x7febdef74b80>),
#  (35103, 'As You Like It.txt', 145, <memory at 0x7febdefd2040>),
#  (35104, 'As You Like It.txt', 146, <memory at 0x7febdefd2100>),
#  (35105, 'As You Like It.txt', 147, <memory at 0x7febdefd21c0>),
#  (35106, 'As You Like It.txt', 148, <memory at 0x7febdefd2280>),
#  (35107, 'As You Like It.txt', 149, <memory at 0x7febdefd2340>),
#  (35108, 'As You Like It.txt', 150, <memory at 0x7febdefd2400>),
#  (35109, 'As You Like It.txt', 151, <memory at 0x7febdefd24c0>),
#  (35110, 'As You Like It.txt', 152, <memory at 0x7febdefd2580>),
#  (35111, 'As You Like It.txt', 153, <memory at 0x7febdefd2640>),
#  (35112, 'As You Like It.txt', 154, <memory at 0x7febdefd2700>),
#  (35113, 'As You Like It.txt', 155, <memory at 0x7febdefd27c0>),
#  (35114, 'As You Like It.txt', 156, <memory at 0x7febdefd2880>),
#  (35115, 'As You Like It.txt', 157, <memory at 0x7febdefd2940>),
#  (35116, 'As You Like It.txt', 158, <memory at 0x7febdefd2a00>),
#  (35117, 'As You Like It.txt', 159, <memory at 0x7febdefd2ac0>),
#  (35118, 'As You Like It.txt', 160, <memory at 0x7febdefd2b80>),
#  (35119, 'As You Like It.txt', 161, <memory at 0x7febdefd2c40>),
#  (35120, 'As You Like It.txt', 162, <memory at 0x7febdefd2d00>),
#  (35121, 'As You Like It.txt', 163, <memory at 0x7febdefd2dc0>),
#  (35122, 'As You Like It.txt', 164, <memory at 0x7febdefd2e80>),
#  (35123, 'As You Like It.txt', 165, <memory at 0x7febdefd2f40>),
#  (35124, 'As You Like It.txt', 166, <memory at 0x7febdefd5040>),
#  (35125, 'As You Like It.txt', 167, <memory at 0x7febdefd5100>),
#  (35126, 'As You Like It.txt', 168, <memory at 0x7febdefd51c0>),
#  (35127, 'As You Like It.txt', 169, <memory at 0x7febdefd5280>),
#  (35128, 'As You Like It.txt', 170, <memory at 0x7febdefd5340>),
#  (35129, 'As You Like It.txt', 171, <memory at 0x7febdefd5400>),
#  (35130, 'As You Like It.txt', 172, <memory at 0x7febdefd54c0>),
#  (35131, 'As You Like It.txt', 173, <memory at 0x7febdefd5580>),
#  (35132, 'As You Like It.txt', 174, <memory at 0x7febdefd5640>),
#  (35133, 'As You Like It.txt', 175, <memory at 0x7febdefd5700>),
#  (35134, 'As You Like It.txt', 176, <memory at 0x7febdefd57c0>),
#  (35135, 'As You Like It.txt', 177, <memory at 0x7febdefd5880>),
#  (35136, 'As You Like It.txt', 178, <memory at 0x7febdefd5940>),
#  (35137, 'As You Like It.txt', 179, <memory at 0x7febdefd5a00>),
#  (35138, 'As You Like It.txt', 180, <memory at 0x7febdefd5ac0>),
#  (35139, 'As You Like It.txt', 181, <memory at 0x7febdefd5b80>),
#  (35140, 'As You Like It.txt', 182, <memory at 0x7febdefd5c40>),
#  (35141, 'As You Like It.txt', 183, <memory at 0x7febdefd5d00>),
#  (35142, 'As You Like It.txt', 184, <memory at 0x7febdefd5dc0>),
#  (35143, 'As You Like It.txt', 185, <memory at 0x7febdefd5e80>),
#  (35144, 'As You Like It.txt', 186, <memory at 0x7febdefd5f40>),
#  (35145, 'As You Like It.txt', 187, <memory at 0x7febdefd7040>),
#  (35146, 'As You Like It.txt', 188, <memory at 0x7febdefd7100>),
#  (35147, 'As You Like It.txt', 189, <memory at 0x7febdefd71c0>),
#  (35148, 'As You Like It.txt', 190, <memory at 0x7febdefd7280>),
#  (35149, 'As You Like It.txt', 191, <memory at 0x7febdefd7340>),
#  (35150, 'As You Like It.txt', 192, <memory at 0x7febdefd7400>),
#  (35151, 'As You Like It.txt', 193, <memory at 0x7febdefd74c0>),
#  (35152, 'As You Like It.txt', 194, <memory at 0x7febdefd7580>),
#  (35153, 'As You Like It.txt', 195, <memory at 0x7febdefd7640>),
#  (35154, 'As You Like It.txt', 196, <memory at 0x7febdefd7700>),
#  (35155, 'As You Like It.txt', 197, <memory at 0x7febdefd77c0>),
#  (35157, 'As You Like It.txt', 199, <memory at 0x7febdefd7880>),
#  (35158, 'As You Like It.txt', 200, <memory at 0x7febdefd7940>),
#  (35159, 'As You Like It.txt', 201, <memory at 0x7febdefd7a00>),
#  (35160, 'As You Like It.txt', 202, <memory at 0x7febdefd7ac0>),
#  (35161, 'As You Like It.txt', 203, <memory at 0x7febdefd7b80>),
#  (35162, 'As You Like It.txt', 204, <memory at 0x7febdefd7c40>),
#  (35163, 'As You Like It.txt', 205, <memory at 0x7febdefd7d00>),
#  (35164, 'As You Like It.txt', 206, <memory at 0x7febdefd7dc0>),
#  (35165, 'As You Like It.txt', 207, <memory at 0x7febdefd7e80>),
#  (35166, 'As You Like It.txt', 208, <memory at 0x7febdefd7f40>),
#  (35167, 'As You Like It.txt', 209, <memory at 0x7febdefda040>),
#  (35168, 'As You Like It.txt', 210, <memory at 0x7febdefda100>),
#  (35169, 'As You Like It.txt', 211, <memory at 0x7febdefda1c0>),
#  (35170, 'As You Like It.txt', 212, <memory at 0x7febdefda280>),
#  (35171, 'As You Like It.txt', 213, <memory at 0x7febdefda340>),
#  (35172, 'As You Like It.txt', 214, <memory at 0x7febdefda400>),
#  (35173, 'As You Like It.txt', 215, <memory at 0x7febdefda4c0>),
#  (35174, 'As You Like It.txt', 216, <memory at 0x7febdefda580>),
#  (35175, 'As You Like It.txt', 217, <memory at 0x7febdefda640>),
#  (35176, 'As You Like It.txt', 218, <memory at 0x7febdefda700>),
#  (35177, 'As You Like It.txt', 219, <memory at 0x7febdefda7c0>),
#  (35178, 'As You Like It.txt', 220, <memory at 0x7febdefda880>),
#  (35179, 'As You Like It.txt', 221, <memory at 0x7febdefda940>),
#  (35180, 'As You Like It.txt', 222, <memory at 0x7febdefdaa00>),
#  (35181, 'As You Like It.txt', 223, <memory at 0x7febdefdaac0>),
#  (35182, 'As You Like It.txt', 224, <memory at 0x7febdefdab80>),
#  (35183, 'As You Like It.txt', 225, <memory at 0x7febdefdac40>),
#  (35184, 'As You Like It.txt', 226, <memory at 0x7febdefdad00>),
#  (35185, 'As You Like It.txt', 227, <memory at 0x7febdefdadc0>),
#  (35186, 'As You Like It.txt', 228, <memory at 0x7febdefdae80>),
#  (35187, 'As You Like It.txt', 229, <memory at 0x7febdefdaf40>),
#  (35188, 'As You Like It.txt', 230, <memory at 0x7febdefdd040>),
#  (35189, 'As You Like It.txt', 231, <memory at 0x7febdefdd100>),
#  (35190, 'As You Like It.txt', 232, <memory at 0x7febdefdd1c0>),
#  (35191, 'As You Like It.txt', 233, <memory at 0x7febdefdd280>),
#  (35192, 'As You Like It.txt', 234, <memory at 0x7febdefdd340>),
#  (35193, 'As You Like It.txt', 235, <memory at 0x7febdefdd400>),
#  (35194, 'As You Like It.txt', 236, <memory at 0x7febdefdd4c0>),
#  (35195, 'As You Like It.txt', 237, <memory at 0x7febdefdd580>),
#  (35196, 'As You Like It.txt', 238, <memory at 0x7febdefdd640>),
#  (35197, 'As You Like It.txt', 239, <memory at 0x7febdefdd700>),
#  (35198, 'As You Like It.txt', 240, <memory at 0x7febdefdd7c0>),
#  (35199, 'As You Like It.txt', 241, <memory at 0x7febdefdd880>),
#  (35200, 'As You Like It.txt', 242, <memory at 0x7febdefdd940>),
#  (35201, 'As You Like It.txt', 243, <memory at 0x7febdefdda00>),
#  (35202, 'As You Like It.txt', 244, <memory at 0x7febdefddac0>),
#  (35203, 'As You Like It.txt', 245, <memory at 0x7febdefddb80>),
#  (35204, 'As You Like It.txt', 246, <memory at 0x7febdefddc40>),
#  (35205, 'As You Like It.txt', 247, <memory at 0x7febdefddd00>),
#  (35206, 'As You Like It.txt', 248, <memory at 0x7febdefdddc0>),
#  (35207, 'As You Like It.txt', 249, <memory at 0x7febdefdde80>),
#  (35208, 'As You Like It.txt', 250, <memory at 0x7febdefddf40>),
#  (35209, 'As You Like It.txt', 251, <memory at 0x7febdefe1040>),
#  (35210, 'As You Like It.txt', 252, <memory at 0x7febdefe1100>),
#  (35211, 'As You Like It.txt', 253, <memory at 0x7febdefe11c0>),
#  (35212, 'As You Like It.txt', 254, <memory at 0x7febdefe1280>),
#  (35213, 'As You Like It.txt', 255, <memory at 0x7febdefe1340>),
#  (35214, 'As You Like It.txt', 256, <memory at 0x7febdefe1400>),
#  (35215, 'As You Like It.txt', 257, <memory at 0x7febdefe14c0>),
#  (35216, 'As You Like It.txt', 258, <memory at 0x7febdefe1580>),
#  (35217, 'As You Like It.txt', 259, <memory at 0x7febdefe1640>),
#  (35218, 'As You Like It.txt', 260, <memory at 0x7febdefe1700>),
#  (35219, 'As You Like It.txt', 261, <memory at 0x7febdefe17c0>),
#  (35220, 'As You Like It.txt', 262, <memory at 0x7febdefe1880>),
#  (35221, 'As You Like It.txt', 263, <memory at 0x7febdefe1940>),
#  (35222, 'As You Like It.txt', 264, <memory at 0x7febdefe1a00>),
#  (35223, 'As You Like It.txt', 265, <memory at 0x7febdefe1ac0>),
#  (35224, 'As You Like It.txt', 266, <memory at 0x7febdefe1b80>),
#  (35225, 'As You Like It.txt', 267, <memory at 0x7febdefe1c40>),
#  (35226, 'As You Like It.txt', 268, <memory at 0x7febdefe1d00>),
#  (35227, 'As You Like It.txt', 269, <memory at 0x7febdefe1dc0>),
#  (35228, 'As You Like It.txt', 270, <memory at 0x7febdefe1e80>),
#  (35229, 'As You Like It.txt', 271, <memory at 0x7febdefe1f40>),
#  (35230, 'As You Like It.txt', 272, <memory at 0x7febdefe3040>),
#  (35231, 'As You Like It.txt', 273, <memory at 0x7febdefe3100>),
#  (35232, 'As You Like It.txt', 274, <memory at 0x7febdefe31c0>),
#  (35233, 'As You Like It.txt', 275, <memory at 0x7febdefe3280>),
#  (35234, 'As You Like It.txt', 276, <memory at 0x7febdefe3340>),
#  (35235, 'As You Like It.txt', 277, <memory at 0x7febdefe3400>),
#  (35236, 'As You Like It.txt', 278, <memory at 0x7febdefe34c0>),
#  (35237, 'As You Like It.txt', 279, <memory at 0x7febdefe3580>),
#  (35238, 'As You Like It.txt', 280, <memory at 0x7febdefe3640>),
#  (35239, 'As You Like It.txt', 281, <memory at 0x7febdefe3700>),
#  (35240, 'As You Like It.txt', 282, <memory at 0x7febdefe37c0>),
#  (35241, 'As You Like It.txt', 283, <memory at 0x7febdefe3880>),
#  (35242, 'As You Like It.txt', 284, <memory at 0x7febdefe3940>),
#  (35243, 'As You Like It.txt', 285, <memory at 0x7febdefe3a00>),
#  (35244, 'As You Like It.txt', 286, <memory at 0x7febdefe3ac0>),
#  (35245, 'As You Like It.txt', 287, <memory at 0x7febdefe3b80>),
#  (35246, 'As You Like It.txt', 288, <memory at 0x7febdefe3c40>),
#  (35247, 'As You Like It.txt', 289, <memory at 0x7febdefe3d00>),
#  (35248, 'As You Like It.txt', 290, <memory at 0x7febdefe3dc0>),
#  (35249, 'As You Like It.txt', 291, <memory at 0x7febdefe3e80>),
#  (35250, 'As You Like It.txt', 292, <memory at 0x7febdefe3f40>),
#  (35251, 'As You Like It.txt', 293, <memory at 0x7febdefe7040>),
#  (35252, 'As You Like It.txt', 294, <memory at 0x7febdefe7100>),
#  (35253, 'As You Like It.txt', 295, <memory at 0x7febdefe71c0>),
#  (35254, 'As You Like It.txt', 296, <memory at 0x7febdefe7280>),
#  (35255, 'As You Like It.txt', 297, <memory at 0x7febdefe7340>),
#  (35256, 'As You Like It.txt', 298, <memory at 0x7febdefe7400>),
#  (35257, 'As You Like It.txt', 299, <memory at 0x7febdefe74c0>),
#  (35258, 'As You Like It.txt', 300, <memory at 0x7febdefe7580>),
#  (35259, 'As You Like It.txt', 301, <memory at 0x7febdefe7640>),
#  (35260, 'As You Like It.txt', 302, <memory at 0x7febdefe7700>),
#  (35261, 'As You Like It.txt', 303, <memory at 0x7febdefe77c0>),
#  (35262, 'As You Like It.txt', 304, <memory at 0x7febdefe7880>),
#  (35263, 'As You Like It.txt', 305, <memory at 0x7febdefe7940>),
#  (35264, 'As You Like It.txt', 306, <memory at 0x7febdefe7a00>),
#  (35265, 'As You Like It.txt', 307, <memory at 0x7febdefe7ac0>),
#  (35266, 'As You Like It.txt', 308, <memory at 0x7febdefe7b80>),
#  (35267, 'As You Like It.txt', 309, <memory at 0x7febdefe7c40>),
#  (35269, 'As You Like It.txt', 311, <memory at 0x7febdefe7d00>),
#  (35270, 'As You Like It.txt', 312, <memory at 0x7febdefe7dc0>),
#  (35271, 'As You Like It.txt', 313, <memory at 0x7febdefe7e80>),
#  (35272, 'As You Like It.txt', 314, <memory at 0x7febdefe7f40>),
#  (35273, 'As You Like It.txt', 315, <memory at 0x7febdefe9040>),
#  (35274, 'As You Like It.txt', 316, <memory at 0x7febdefe9100>),
#  (35275, 'As You Like It.txt', 317, <memory at 0x7febdefe91c0>),
#  (35276, 'As You Like It.txt', 318, <memory at 0x7febdefe9280>),
#  (35277, 'As You Like It.txt', 319, <memory at 0x7febdefe9340>),
#  (35278, 'As You Like It.txt', 320, <memory at 0x7febdefe9400>),
#  (35279, 'As You Like It.txt', 321, <memory at 0x7febdefe94c0>),
#  (35280, 'As You Like It.txt', 322, <memory at 0x7febdefe9580>),
#  (35281, 'As You Like It.txt', 323, <memory at 0x7febdefe9640>),
#  (35282, 'As You Like It.txt', 324, <memory at 0x7febdefe9700>),
#  (35283, 'As You Like It.txt', 325, <memory at 0x7febdefe97c0>),
#  (35284, 'As You Like It.txt', 326, <memory at 0x7febdefe9880>),
#  (35285, 'As You Like It.txt', 327, <memory at 0x7febdefe9940>),
#  (35286, 'As You Like It.txt', 328, <memory at 0x7febdefe9a00>),
#  (35287, 'As You Like It.txt', 329, <memory at 0x7febdefe9ac0>),
#  (35288, 'As You Like It.txt', 330, <memory at 0x7febdefe9b80>),
#  (35289, 'As You Like It.txt', 331, <memory at 0x7febdefe9c40>),
#  (35290, 'As You Like It.txt', 332, <memory at 0x7febdefe9d00>),
#  (35291, 'As You Like It.txt', 333, <memory at 0x7febdefe9dc0>),
#  (35292, 'As You Like It.txt', 334, <memory at 0x7febdefe9e80>),
#  (35293, 'As You Like It.txt', 335, <memory at 0x7febdefe9f40>),
#  (35294, 'As You Like It.txt', 336, <memory at 0x7febdefec040>),
#  (35295, 'As You Like It.txt', 337, <memory at 0x7febdefec100>),
#  (35296, 'As You Like It.txt', 338, <memory at 0x7febdefec1c0>),
#  (35297, 'As You Like It.txt', 339, <memory at 0x7febdefec280>),
#  (35298, 'As You Like It.txt', 340, <memory at 0x7febdefec340>),
#  (35299, 'As You Like It.txt', 341, <memory at 0x7febdefec400>),
#  (35300, 'As You Like It.txt', 342, <memory at 0x7febdefec4c0>),
#  (35301, 'As You Like It.txt', 343, <memory at 0x7febdefec580>),
#  (35302, 'As You Like It.txt', 344, <memory at 0x7febdefec640>),
#  (35303, 'As You Like It.txt', 345, <memory at 0x7febdefec700>),
#  (35304, 'As You Like It.txt', 346, <memory at 0x7febdefec7c0>),
#  (35305, 'As You Like It.txt', 347, <memory at 0x7febdefec880>),
#  (35306, 'As You Like It.txt', 348, <memory at 0x7febdefec940>),
#  (35307, 'As You Like It.txt', 349, <memory at 0x7febdefeca00>),
#  (35308, 'As You Like It.txt', 350, <memory at 0x7febdefecac0>),
#  (35309, 'As You Like It.txt', 351, <memory at 0x7febdefecb80>),
#  (35310, 'As You Like It.txt', 352, <memory at 0x7febdefecc40>),
#  (35311, 'As You Like It.txt', 353, <memory at 0x7febdefecd00>),
#  (35312, 'As You Like It.txt', 354, <memory at 0x7febdefecdc0>),
#  (35313, 'As You Like It.txt', 355, <memory at 0x7febdefece80>),
#  (35314, 'As You Like It.txt', 356, <memory at 0x7febdefecf40>),
#  (35315, 'As You Like It.txt', 357, <memory at 0x7febdefef040>),
#  (35316, 'As You Like It.txt', 358, <memory at 0x7febdefef100>),
#  (35317, 'As You Like It.txt', 359, <memory at 0x7febdefef1c0>),
#  (35318, 'As You Like It.txt', 360, <memory at 0x7febdefef280>),
#  (35319, 'As You Like It.txt', 361, <memory at 0x7febdefef340>),
#  (35320, 'As You Like It.txt', 362, <memory at 0x7febdefef400>),
#  (35321, 'As You Like It.txt', 363, <memory at 0x7febdefef4c0>),
#  (35322, 'As You Like It.txt', 364, <memory at 0x7febdefef580>),
#  (35323, 'As You Like It.txt', 365, <memory at 0x7febdefef640>),
#  (35324, 'As You Like It.txt', 366, <memory at 0x7febdefef700>),
#  (35325, 'As You Like It.txt', 367, <memory at 0x7febdefef7c0>),
#  (35326, 'As You Like It.txt', 368, <memory at 0x7febdefef880>),
#  (35327, 'As You Like It.txt', 369, <memory at 0x7febdefef940>),
#  (35328, 'As You Like It.txt', 370, <memory at 0x7febdefefa00>),
#  (35329, 'As You Like It.txt', 371, <memory at 0x7febdefefac0>),
#  (35330, 'As You Like It.txt', 372, <memory at 0x7febdefefb80>),
#  (35331, 'As You Like It.txt', 373, <memory at 0x7febdefefc40>),
#  (35332, 'As You Like It.txt', 374, <memory at 0x7febdefefd00>),
#  (35333, 'As You Like It.txt', 375, <memory at 0x7febdefefdc0>),
#  (35334, 'As You Like It.txt', 376, <memory at 0x7febdefefe80>),
#  (35335, 'As You Like It.txt', 377, <memory at 0x7febdefeff40>),
#  (35336, 'As You Like It.txt', 378, <memory at 0x7febdeff3040>),
#  (35337, 'As You Like It.txt', 379, <memory at 0x7febdeff3100>),
#  (35338, 'As You Like It.txt', 380, <memory at 0x7febdeff31c0>),
#  (35339, 'As You Like It.txt', 381, <memory at 0x7febdeff3280>),
#  (35340, 'As You Like It.txt', 382, <memory at 0x7febdeff3340>),
#  (35341, 'As You Like It.txt', 383, <memory at 0x7febdeff3400>),
#  (35342, 'As You Like It.txt', 384, <memory at 0x7febdeff34c0>),
#  (35343, 'As You Like It.txt', 385, <memory at 0x7febdeff3580>),
#  (35344, 'As You Like It.txt', 386, <memory at 0x7febdeff3640>),
#  (35345, 'As You Like It.txt', 387, <memory at 0x7febdeff3700>),
#  (35346, 'As You Like It.txt', 388, <memory at 0x7febdeff37c0>),
#  (35347, 'As You Like It.txt', 389, <memory at 0x7febdeff3880>),
#  (35348, 'As You Like It.txt', 390, <memory at 0x7febdeff3940>),
#  (35349, 'As You Like It.txt', 391, <memory at 0x7febdeff3a00>),
#  (35350, 'As You Like It.txt', 392, <memory at 0x7febdeff3ac0>),
#  (35351, 'As You Like It.txt', 393, <memory at 0x7febdeff3b80>),
#  (35352, 'As You Like It.txt', 394, <memory at 0x7febdeff3c40>),
#  (35353, 'As You Like It.txt', 395, <memory at 0x7febdeff3d00>),
#  (35354, 'As You Like It.txt', 396, <memory at 0x7febdeff3dc0>),
#  (35355, 'As You Like It.txt', 397, <memory at 0x7febdeff3e80>),
#  (35356, 'As You Like It.txt', 398, <memory at 0x7febdeff3f40>),
#  (35357, 'As You Like It.txt', 399, <memory at 0x7febdeff5040>),
#  (35358, 'As You Like It.txt', 400, <memory at 0x7febdeff5100>),
#  (35359, 'As You Like It.txt', 401, <memory at 0x7febdeff51c0>),
#  (35360, 'As You Like It.txt', 402, <memory at 0x7febdeff5280>),
#  (35361, 'As You Like It.txt', 403, <memory at 0x7febdeff5340>),
#  (35362, 'As You Like It.txt', 404, <memory at 0x7febdeff5400>),
#  (35363, 'As You Like It.txt', 405, <memory at 0x7febdeff54c0>),
#  (35364, 'As You Like It.txt', 406, <memory at 0x7febdeff5580>),
#  (35365, 'As You Like It.txt', 407, <memory at 0x7febdeff5640>),
#  (35366, 'As You Like It.txt', 408, <memory at 0x7febdeff5700>),
#  (35367, 'As You Like It.txt', 409, <memory at 0x7febdeff57c0>),
#  (35368, 'As You Like It.txt', 410, <memory at 0x7febdeff5880>),
#  (35369, 'As You Like It.txt', 411, <memory at 0x7febdeff5940>),
#  (35370, 'As You Like It.txt', 412, <memory at 0x7febdeff5a00>),
#  (35371, 'As You Like It.txt', 413, <memory at 0x7febdeff5ac0>),
#  (35372, 'As You Like It.txt', 414, <memory at 0x7febdeff5b80>),
#  (35373, 'As You Like It.txt', 415, <memory at 0x7febdeff5c40>),
#  (35374, 'As You Like It.txt', 416, <memory at 0x7febdeff5d00>),
#  (35375, 'As You Like It.txt', 417, <memory at 0x7febdeff5dc0>),
#  (35376, 'As You Like It.txt', 418, <memory at 0x7febdeff5e80>),
#  (35377, 'As You Like It.txt', 419, <memory at 0x7febdeff5f40>),
#  (35378, 'As You Like It.txt', 420, <memory at 0x7febdeff9040>),
#  (35379, 'As You Like It.txt', 421, <memory at 0x7febdeff9100>),
#  (35380, 'As You Like It.txt', 422, <memory at 0x7febdeff91c0>),
#  (35381, 'As You Like It.txt', 423, <memory at 0x7febdeff9280>),
#  (35382, 'As You Like It.txt', 424, <memory at 0x7febdeff9340>),
#  (35383, 'As You Like It.txt', 425, <memory at 0x7febdeff9400>),
#  (35384, 'As You Like It.txt', 426, <memory at 0x7febdeff94c0>),
#  (35385, 'As You Like It.txt', 427, <memory at 0x7febdeff9580>),
#  (35386, 'As You Like It.txt', 428, <memory at 0x7febdeff9640>),
#  (35387, 'As You Like It.txt', 429, <memory at 0x7febdeff9700>),
#  (35388, 'As You Like It.txt', 430, <memory at 0x7febdeff97c0>),
#  (35389, 'As You Like It.txt', 431, <memory at 0x7febdeff9880>),
#  (35390, 'As You Like It.txt', 432, <memory at 0x7febdeff9940>),
#  (35391, 'As You Like It.txt', 433, <memory at 0x7febdeff9a00>),
#  (35392, 'As You Like It.txt', 434, <memory at 0x7febdeff9ac0>),
#  (35393, 'As You Like It.txt', 435, <memory at 0x7febdeff9b80>),
#  (35394, 'As You Like It.txt', 436, <memory at 0x7febdeff9c40>),
#  (35395, 'As You Like It.txt', 437, <memory at 0x7febdeff9d00>),
#  (35396, 'As You Like It.txt', 438, <memory at 0x7febdeff9dc0>),
#  (35397, 'As You Like It.txt', 439, <memory at 0x7febdeff9e80>),
#  (35398, 'As You Like It.txt', 440, <memory at 0x7febdeff9f40>),
#  (35399, 'As You Like It.txt', 441, <memory at 0x7febdeffb040>),
#  (35400, 'As You Like It.txt', 442, <memory at 0x7febdeffb100>),
#  (35401, 'As You Like It.txt', 443, <memory at 0x7febdeffb1c0>),
#  (35402, 'As You Like It.txt', 444, <memory at 0x7febdeffb280>),
#  (35403, 'As You Like It.txt', 445, <memory at 0x7febdeffb340>),
#  (35404, 'As You Like It.txt', 446, <memory at 0x7febdeffb400>),
#  (35405, 'As You Like It.txt', 447, <memory at 0x7febdeffb4c0>),
#  (35406, 'As You Like It.txt', 448, <memory at 0x7febdeffb580>),
#  (35407, 'As You Like It.txt', 449, <memory at 0x7febdeffb640>),
#  (35408, 'As You Like It.txt', 450, <memory at 0x7febdeffb700>),
#  (35409, 'As You Like It.txt', 451, <memory at 0x7febdeffb7c0>),
#  (35410, 'As You Like It.txt', 452, <memory at 0x7febdeffb880>),
#  (35411, 'As You Like It.txt', 453, <memory at 0x7febdeffb940>),
#  (35412, 'As You Like It.txt', 454, <memory at 0x7febdeffba00>),
#  (35413, 'As You Like It.txt', 455, <memory at 0x7febdeffbac0>),
#  (35414, 'As You Like It.txt', 456, <memory at 0x7febdeffbb80>),
#  (35415, 'As You Like It.txt', 457, <memory at 0x7febdeffbc40>),
#  (35416, 'As You Like It.txt', 458, <memory at 0x7febdeffbd00>),
#  (35417, 'As You Like It.txt', 459, <memory at 0x7febdeffbdc0>),
#  (35418, 'As You Like It.txt', 460, <memory at 0x7febdeffbe80>),
#  (35419, 'As You Like It.txt', 461, <memory at 0x7febdeffbf40>),
#  (35420, 'As You Like It.txt', 462, <memory at 0x7febdeffe040>),
#  (35421, 'As You Like It.txt', 463, <memory at 0x7febdeffe100>),
#  (35422, 'As You Like It.txt', 464, <memory at 0x7febdeffe1c0>),
#  (35423, 'As You Like It.txt', 465, <memory at 0x7febdeffe280>),
#  (35424, 'As You Like It.txt', 466, <memory at 0x7febdeffe340>),
#  (35425, 'As You Like It.txt', 467, <memory at 0x7febdeffe400>),
#  (35426, 'As You Like It.txt', 468, <memory at 0x7febdeffe4c0>),
#  (35427, 'As You Like It.txt', 469, <memory at 0x7febdeffe580>),
#  (35428, 'As You Like It.txt', 470, <memory at 0x7febdeffe640>),
#  (35429, 'As You Like It.txt', 471, <memory at 0x7febdeffe700>),
#  (35430, 'As You Like It.txt', 472, <memory at 0x7febdeffe7c0>),
#  (35431, 'As You Like It.txt', 473, <memory at 0x7febdeffe880>),
#  (35432, 'As You Like It.txt', 474, <memory at 0x7febdeffe940>),
#  (35433, 'As You Like It.txt', 475, <memory at 0x7febdeffea00>),
#  (35434, 'As You Like It.txt', 476, <memory at 0x7febdeffeac0>),
#  (35435, 'As You Like It.txt', 477, <memory at 0x7febdeffeb80>),
#  (35436, 'As You Like It.txt', 478, <memory at 0x7febdeffec40>),
#  (35437, 'As You Like It.txt', 479, <memory at 0x7febdeffed00>),
#  (35438, 'As You Like It.txt', 480, <memory at 0x7febdeffedc0>),
#  (35439, 'As You Like It.txt', 481, <memory at 0x7febdeffee80>),
#  (35440, 'As You Like It.txt', 482, <memory at 0x7febdeffef40>),
#  (35441, 'As You Like It.txt', 483, <memory at 0x7febc1cd9040>),
#  (35442, 'As You Like It.txt', 484, <memory at 0x7febc1cd9100>),
#  (35443, 'As You Like It.txt', 485, <memory at 0x7febc1cd91c0>),
#  (35444, 'As You Like It.txt', 486, <memory at 0x7febc1cd9280>),
#  (35445, 'As You Like It.txt', 487, <memory at 0x7febc1cd9340>),
#  (35446, 'As You Like It.txt', 488, <memory at 0x7febc1cd9400>),
#  (35447, 'As You Like It.txt', 489, <memory at 0x7febc1cd94c0>),
#  (35448, 'As You Like It.txt', 490, <memory at 0x7febc1cd9580>),
#  (35449, 'As You Like It.txt', 491, <memory at 0x7febc1cd9640>),
#  (35450, 'As You Like It.txt', 492, <memory at 0x7febc1cd9700>),
#  (35451, 'As You Like It.txt', 493, <memory at 0x7febc1cd97c0>),
#  (35452, 'As You Like It.txt', 494, <memory at 0x7febc1cd9880>),
#  (35453, 'As You Like It.txt', 495, <memory at 0x7febc1cd9940>),
#  (35454, 'As You Like It.txt', 496, <memory at 0x7febc1cd9a00>),
#  (35455, 'As You Like It.txt', 497, <memory at 0x7febc1cd9ac0>),
#  (35456, 'As You Like It.txt', 498, <memory at 0x7febc1cd9b80>),
#  (35457, 'As You Like It.txt', 499, <memory at 0x7febc1cd9c40>),
#  (35458, 'As You Like It.txt', 500, <memory at 0x7febc1cd9d00>),
#  (35459, 'As You Like It.txt', 501, <memory at 0x7febc1cd9dc0>),
#  (35460, 'As You Like It.txt', 502, <memory at 0x7febc1cd9e80>),
#  (35461, 'As You Like It.txt', 503, <memory at 0x7febc1cd9f40>),
#  (35462, 'As You Like It.txt', 504, <memory at 0x7febc1cdd040>),
#  (35463, 'As You Like It.txt', 505, <memory at 0x7febc1cdd100>),
#  (35464, 'As You Like It.txt', 506, <memory at 0x7febc1cdd1c0>),
#  (35465, 'As You Like It.txt', 507, <memory at 0x7febc1cdd280>),
#  (35466, 'As You Like It.txt', 508, <memory at 0x7febc1cdd340>),
#  (35467, 'As You Like It.txt', 509, <memory at 0x7febc1cdd400>),
#  (35468, 'As You Like It.txt', 510, <memory at 0x7febc1cdd4c0>),
#  (35469, 'As You Like It.txt', 511, <memory at 0x7febc1cdd580>),
#  (35470, 'As You Like It.txt', 512, <memory at 0x7febc1cdd640>),
#  (35471, 'As You Like It.txt', 513, <memory at 0x7febc1cdd700>),
#  (35472, 'As You Like It.txt', 514, <memory at 0x7febc1cdd7c0>),
#  (35473, 'As You Like It.txt', 515, <memory at 0x7febc1cdd880>),
#  (35474, 'As You Like It.txt', 516, <memory at 0x7febc1cdd940>),
#  (35475, 'As You Like It.txt', 517, <memory at 0x7febc1cdda00>),
#  (35476, 'As You Like It.txt', 518, <memory at 0x7febc1cddac0>),
#  (35477, 'As You Like It.txt', 519, <memory at 0x7febc1cddb80>),
#  (35478, 'As You Like It.txt', 520, <memory at 0x7febc1cddc40>),
#  (35479, 'As You Like It.txt', 521, <memory at 0x7febc1cddd00>),
#  (35480, 'As You Like It.txt', 522, <memory at 0x7febc1cdddc0>),
#  (35481, 'As You Like It.txt', 523, <memory at 0x7febc1cdde80>),
#  (35482, 'As You Like It.txt', 524, <memory at 0x7febc1cddf40>),
#  (35483, 'As You Like It.txt', 525, <memory at 0x7febc1cdf040>),
#  (35484, 'As You Like It.txt', 526, <memory at 0x7febc1cdf100>),
#  (35485, 'As You Like It.txt', 527, <memory at 0x7febc1cdf1c0>),
#  (35486, 'As You Like It.txt', 528, <memory at 0x7febc1cdf280>),
#  (35487, 'As You Like It.txt', 529, <memory at 0x7febc1cdf340>),
#  (35488, 'As You Like It.txt', 530, <memory at 0x7febc1cdf400>),
#  (35489, 'As You Like It.txt', 531, <memory at 0x7febc1cdf4c0>),
#  (35490, 'As You Like It.txt', 532, <memory at 0x7febc1cdf580>),
#  (35491, 'As You Like It.txt', 533, <memory at 0x7febc1cdf640>),
#  (35492, 'As You Like It.txt', 534, <memory at 0x7febc1cdf700>),
#  (35493, 'As You Like It.txt', 535, <memory at 0x7febc1cdf7c0>),
#  (35494, 'As You Like It.txt', 536, <memory at 0x7febc1cdf880>),
#  (35495, 'As You Like It.txt', 537, <memory at 0x7febc1cdf940>),
#  (35496, 'As You Like It.txt', 538, <memory at 0x7febc1cdfa00>),
#  (35497, 'As You Like It.txt', 539, <memory at 0x7febc1cdfac0>),
#  (35498, 'As You Like It.txt', 540, <memory at 0x7febc1cdfb80>),
#  (35499, 'As You Like It.txt', 541, <memory at 0x7febc1cdfc40>),
#  (35500, 'As You Like It.txt', 542, <memory at 0x7febc1cdfd00>),
#  (35501, 'As You Like It.txt', 543, <memory at 0x7febc1cdfdc0>),
#  (35502, 'As You Like It.txt', 544, <memory at 0x7febc1cdfe80>),
#  (35503, 'As You Like It.txt', 545, <memory at 0x7febc1cdff40>),
#  (35504, 'As You Like It.txt', 546, <memory at 0x7febc1ce3040>),
#  (35505, 'As You Like It.txt', 547, <memory at 0x7febc1ce3100>),
#  (35506, 'As You Like It.txt', 548, <memory at 0x7febc1ce31c0>),
#  (35507, 'As You Like It.txt', 549, <memory at 0x7febc1ce3280>),
#  (35508, 'As You Like It.txt', 550, <memory at 0x7febc1ce3340>),
#  (35509, 'As You Like It.txt', 551, <memory at 0x7febc1ce3400>),
#  (35510, 'As You Like It.txt', 552, <memory at 0x7febc1ce34c0>),
#  (35511, 'As You Like It.txt', 553, <memory at 0x7febc1ce3580>),
#  (35512, 'As You Like It.txt', 554, <memory at 0x7febc1ce3640>),
#  (35513, 'As You Like It.txt', 555, <memory at 0x7febc1ce3700>),
#  (35514, 'As You Like It.txt', 556, <memory at 0x7febc1ce37c0>),
#  (35515, 'As You Like It.txt', 557, <memory at 0x7febc1ce3880>),
#  (35516, 'As You Like It.txt', 558, <memory at 0x7febc1ce3940>),
#  (35517, 'As You Like It.txt', 559, <memory at 0x7febc1ce3a00>),
#  (35518, 'As You Like It.txt', 560, <memory at 0x7febc1ce3ac0>),
#  (35519, 'As You Like It.txt', 561, <memory at 0x7febc1ce3b80>),
#  (35520, 'As You Like It.txt', 562, <memory at 0x7febc1ce3c40>),
#  (35521, 'As You Like It.txt', 563, <memory at 0x7febc1ce3d00>),
#  (35522, 'As You Like It.txt', 564, <memory at 0x7febc1ce3dc0>),
#  (35523, 'As You Like It.txt', 565, <memory at 0x7febc1ce3e80>),
#  (35524, 'As You Like It.txt', 566, <memory at 0x7febc1ce3f40>),
#  (35525, 'As You Like It.txt', 567, <memory at 0x7febc1ce6040>),
#  (35526, 'As You Like It.txt', 568, <memory at 0x7febc1ce6100>),
#  (35527, 'As You Like It.txt', 569, <memory at 0x7febc1ce61c0>),
#  (35528, 'As You Like It.txt', 570, <memory at 0x7febc1ce6280>),
#  (35529, 'As You Like It.txt', 571, <memory at 0x7febc1ce6340>),
#  (35530, 'As You Like It.txt', 572, <memory at 0x7febc1ce6400>),
#  (35531, 'As You Like It.txt', 573, <memory at 0x7febc1ce64c0>),
#  (35532, 'As You Like It.txt', 574, <memory at 0x7febc1ce6580>),
#  (35533, 'As You Like It.txt', 575, <memory at 0x7febc1ce6640>),
#  (35534, 'As You Like It.txt', 576, <memory at 0x7febc1ce6700>),
#  (35535, 'As You Like It.txt', 577, <memory at 0x7febc1ce67c0>),
#  (35536, 'As You Like It.txt', 578, <memory at 0x7febc1ce6880>),
#  (35537, 'As You Like It.txt', 579, <memory at 0x7febc1ce6940>),
#  (35538, 'As You Like It.txt', 580, <memory at 0x7febc1ce6a00>),
#  (35539, 'As You Like It.txt', 581, <memory at 0x7febc1ce6ac0>),
#  (35540, 'As You Like It.txt', 582, <memory at 0x7febc1ce6b80>),
#  (35541, 'As You Like It.txt', 583, <memory at 0x7febc1ce6c40>),
#  (35542, 'As You Like It.txt', 584, <memory at 0x7febc1ce6d00>),
#  (35543, 'As You Like It.txt', 585, <memory at 0x7febc1ce6dc0>),
#  (35544, 'As You Like It.txt', 586, <memory at 0x7febc1ce6e80>),
#  (35545, 'As You Like It.txt', 587, <memory at 0x7febc1ce6f40>),
#  (35546, 'As You Like It.txt', 588, <memory at 0x7febc1ce8040>),
#  (35547, 'As You Like It.txt', 589, <memory at 0x7febc1ce8100>),
#  (35548, 'As You Like It.txt', 590, <memory at 0x7febc1ce81c0>),
#  (35549, 'As You Like It.txt', 591, <memory at 0x7febc1ce8280>),
#  (35550, 'As You Like It.txt', 592, <memory at 0x7febc1ce8340>),
#  (35551, 'As You Like It.txt', 593, <memory at 0x7febc1ce8400>),
#  (35552, 'As You Like It.txt', 594, <memory at 0x7febc1ce84c0>),
#  (35553, 'As You Like It.txt', 595, <memory at 0x7febc1ce8580>),
#  (35554, 'As You Like It.txt', 596, <memory at 0x7febc1ce8640>),
#  (35555, 'As You Like It.txt', 597, <memory at 0x7febc1ce8700>),
#  (35556, 'As You Like It.txt', 598, <memory at 0x7febc1ce87c0>),
#  (35557, 'As You Like It.txt', 599, <memory at 0x7febc1ce8880>),
#  (35558, 'As You Like It.txt', 600, <memory at 0x7febc1ce8940>),
#  (35559, 'As You Like It.txt', 601, <memory at 0x7febc1ce8a00>),
#  (35560, 'As You Like It.txt', 602, <memory at 0x7febc1ce8ac0>),
#  (35561, 'As You Like It.txt', 603, <memory at 0x7febc1ce8b80>),
#  (35562, 'As You Like It.txt', 604, <memory at 0x7febc1ce8c40>),
#  (35563, 'As You Like It.txt', 605, <memory at 0x7febc1ce8d00>),
#  (35564, 'As You Like It.txt', 606, <memory at 0x7febc1ce8dc0>),
#  (35565, 'As You Like It.txt', 607, <memory at 0x7febc1ce8e80>),
#  (35566, 'As You Like It.txt', 608, <memory at 0x7febc1ce8f40>),
#  (35567, 'As You Like It.txt', 609, <memory at 0x7febc1ceb040>),
#  (35568, 'As You Like It.txt', 610, <memory at 0x7febc1ceb100>),
#  (35569, 'As You Like It.txt', 611, <memory at 0x7febc1ceb1c0>),
#  (35570, 'As You Like It.txt', 612, <memory at 0x7febc1ceb280>),
#  (35571, 'As You Like It.txt', 613, <memory at 0x7febc1ceb340>),
#  (35572, 'As You Like It.txt', 614, <memory at 0x7febc1ceb400>),
#  (35573, 'As You Like It.txt', 615, <memory at 0x7febc1ceb4c0>),
#  (35574, 'As You Like It.txt', 616, <memory at 0x7febc1ceb580>),
#  (35575, 'As You Like It.txt', 617, <memory at 0x7febc1ceb640>),
#  (35576, 'As You Like It.txt', 618, <memory at 0x7febc1ceb700>),
#  (35577, 'As You Like It.txt', 619, <memory at 0x7febc1ceb7c0>),
#  (35578, 'As You Like It.txt', 620, <memory at 0x7febc1ceb880>),
#  (35579, 'As You Like It.txt', 621, <memory at 0x7febc1ceb940>),
#  (35580, 'As You Like It.txt', 622, <memory at 0x7febc1ceba00>),
#  (35581, 'As You Like It.txt', 623, <memory at 0x7febc1cebac0>),
#  (35582, 'As You Like It.txt', 624, <memory at 0x7febc1cebb80>),
#  (35583, 'As You Like It.txt', 625, <memory at 0x7febc1cebc40>),
#  (35584, 'As You Like It.txt', 626, <memory at 0x7febc1cebd00>),
#  (35585, 'As You Like It.txt', 627, <memory at 0x7febc1cebdc0>),
#  (35586, 'As You Like It.txt', 628, <memory at 0x7febc1cebe80>),
#  (35587, 'As You Like It.txt', 629, <memory at 0x7febc1cebf40>),
#  (35588, 'As You Like It.txt', 630, <memory at 0x7febc1cef040>),
#  (35589, 'As You Like It.txt', 631, <memory at 0x7febc1cef100>),
#  (35590, 'As You Like It.txt', 632, <memory at 0x7febc1cef1c0>),
#  (35591, 'As You Like It.txt', 633, <memory at 0x7febc1cef280>),
#  (35592, 'As You Like It.txt', 634, <memory at 0x7febc1cef340>),
#  (35593, 'As You Like It.txt', 635, <memory at 0x7febc1cef400>),
#  (35594, 'As You Like It.txt', 636, <memory at 0x7febc1cef4c0>),
#  (35595, 'As You Like It.txt', 637, <memory at 0x7febc1cef580>),
#  (35596, 'As You Like It.txt', 638, <memory at 0x7febc1cef640>),
#  (35597, 'As You Like It.txt', 639, <memory at 0x7febc1cef700>),
#  (35598, 'As You Like It.txt', 640, <memory at 0x7febc1cef7c0>),
#  (35599, 'As You Like It.txt', 641, <memory at 0x7febc1cef880>),
#  (35600, 'As You Like It.txt', 642, <memory at 0x7febc1cef940>),
#  (35601, 'As You Like It.txt', 643, <memory at 0x7febc1cefa00>),
#  (35602, 'As You Like It.txt', 644, <memory at 0x7febc1cefac0>),
#  (35603, 'As You Like It.txt', 645, <memory at 0x7febc1cefb80>),
#  (35604, 'As You Like It.txt', 646, <memory at 0x7febc1cefc40>),
#  (35605, 'As You Like It.txt', 647, <memory at 0x7febc1cefd00>),
#  (35606, 'As You Like It.txt', 648, <memory at 0x7febc1cefdc0>),
#  (35607, 'As You Like It.txt', 649, <memory at 0x7febc1cefe80>),
#  (35608, 'As You Like It.txt', 650, <memory at 0x7febc1ceff40>),
#  (35609, 'As You Like It.txt', 651, <memory at 0x7febc1cf1040>),
#  (35610, 'As You Like It.txt', 652, <memory at 0x7febc1cf1100>),
#  (35611, 'As You Like It.txt', 653, <memory at 0x7febc1cf11c0>),
#  (35612, 'As You Like It.txt', 654, <memory at 0x7febc1cf1280>),
#  (35613, 'As You Like It.txt', 655, <memory at 0x7febc1cf1340>),
#  (35614, 'As You Like It.txt', 656, <memory at 0x7febc1cf1400>),
#  (35615, 'As You Like It.txt', 657, <memory at 0x7febc1cf14c0>),
#  (35616, 'As You Like It.txt', 658, <memory at 0x7febc1cf1580>),
#  (35617, 'As You Like It.txt', 659, <memory at 0x7febc1cf1640>),
#  (35618, 'As You Like It.txt', 660, <memory at 0x7febc1cf1700>),
#  (35619, 'As You Like It.txt', 661, <memory at 0x7febc1cf17c0>),
#  (35621, 'As You Like It.txt', 663, <memory at 0x7febc1cf1880>),
#  (35622, 'As You Like It.txt', 664, <memory at 0x7febc1cf1940>),
#  (35623, 'As You Like It.txt', 665, <memory at 0x7febc1cf1a00>),
#  (35624, 'As You Like It.txt', 666, <memory at 0x7febc1cf1ac0>),
#  (35625, 'As You Like It.txt', 667, <memory at 0x7febc1cf1b80>),
#  (35626, 'As You Like It.txt', 668, <memory at 0x7febc1cf1c40>),
#  (35627, 'As You Like It.txt', 669, <memory at 0x7febc1cf1d00>),
#  (35628, 'As You Like It.txt', 670, <memory at 0x7febc1cf1dc0>),
#  (35629, 'As You Like It.txt', 671, <memory at 0x7febc1cf1e80>),
#  (35630, 'As You Like It.txt', 672, <memory at 0x7febc1cf1f40>),
#  (35631, 'As You Like It.txt', 673, <memory at 0x7febc1cf5040>),
#  (35632, 'As You Like It.txt', 674, <memory at 0x7febc1cf5100>),
#  (35633, 'As You Like It.txt', 675, <memory at 0x7febc1cf51c0>),
#  (35634, 'As You Like It.txt', 676, <memory at 0x7febc1cf5280>),
#  (35635, 'As You Like It.txt', 677, <memory at 0x7febc1cf5340>),
#  (35636, 'As You Like It.txt', 678, <memory at 0x7febc1cf5400>),
#  (35637, 'As You Like It.txt', 679, <memory at 0x7febc1cf54c0>),
#  (35638, 'As You Like It.txt', 680, <memory at 0x7febc1cf5580>),
#  (35639, 'As You Like It.txt', 681, <memory at 0x7febc1cf5640>),
#  (35640, 'As You Like It.txt', 682, <memory at 0x7febc1cf5700>),
#  (35641, 'As You Like It.txt', 683, <memory at 0x7febc1cf57c0>),
#  (35642, 'As You Like It.txt', 684, <memory at 0x7febc1cf5880>),
#  (35643, 'As You Like It.txt', 685, <memory at 0x7febc1cf5940>),
#  (35644, 'As You Like It.txt', 686, <memory at 0x7febc1cf5a00>),
#  (35645, 'As You Like It.txt', 687, <memory at 0x7febc1cf5ac0>),
#  (35646, 'As You Like It.txt', 688, <memory at 0x7febc1cf5b80>),
#  (35647, 'As You Like It.txt', 689, <memory at 0x7febc1cf5c40>),
#  (35648, 'As You Like It.txt', 690, <memory at 0x7febc1cf5d00>),
#  (35649, 'As You Like It.txt', 691, <memory at 0x7febc1cf5dc0>),
#  (35650, 'As You Like It.txt', 692, <memory at 0x7febc1cf5e80>),
#  (35651, 'As You Like It.txt', 693, <memory at 0x7febc1cf5f40>),
#  (35652, 'As You Like It.txt', 694, <memory at 0x7febc1cf8040>),
#  (35653, 'As You Like It.txt', 695, <memory at 0x7febc1cf8100>),
#  (35654, 'As You Like It.txt', 696, <memory at 0x7febc1cf81c0>),
#  (35655, 'As You Like It.txt', 697, <memory at 0x7febc1cf8280>),
#  (35656, 'As You Like It.txt', 698, <memory at 0x7febc1cf8340>),
#  (35657, 'As You Like It.txt', 699, <memory at 0x7febc1cf8400>),
#  (35658, 'As You Like It.txt', 700, <memory at 0x7febc1cf84c0>),
#  (35659, 'As You Like It.txt', 701, <memory at 0x7febc1cf8580>),
#  (35660, 'As You Like It.txt', 702, <memory at 0x7febc1cf8640>),
#  (35661, 'As You Like It.txt', 703, <memory at 0x7febc1cf8700>),
#  (35662, 'As You Like It.txt', 704, <memory at 0x7febc1cf87c0>),
#  (35663, 'As You Like It.txt', 705, <memory at 0x7febc1cf8880>),
#  (35664, 'As You Like It.txt', 706, <memory at 0x7febc1cf8940>),
#  (35665, 'As You Like It.txt', 707, <memory at 0x7febc1cf8a00>),
#  (35666, 'As You Like It.txt', 708, <memory at 0x7febc1cf8ac0>),
#  (35667, 'As You Like It.txt', 709, <memory at 0x7febc1cf8b80>),
#  (35668, 'As You Like It.txt', 710, <memory at 0x7febc1cf8c40>),
#  (35669, 'As You Like It.txt', 711, <memory at 0x7febc1cf8d00>),
#  (35670, 'As You Like It.txt', 712, <memory at 0x7febc1cf8dc0>),
#  (35671, 'As You Like It.txt', 713, <memory at 0x7febc1cf8e80>),
#  (35672, 'As You Like It.txt', 714, <memory at 0x7febc1cf8f40>),
#  (35673, 'As You Like It.txt', 715, <memory at 0x7febc1cfa040>),
#  (35674, 'As You Like It.txt', 716, <memory at 0x7febc1cfa100>),
#  (35675, 'As You Like It.txt', 717, <memory at 0x7febc1cfa1c0>),
#  (35676, 'As You Like It.txt', 718, <memory at 0x7febc1cfa280>),
#  (35677, 'As You Like It.txt', 719, <memory at 0x7febc1cfa340>),
#  (35678, 'As You Like It.txt', 720, <memory at 0x7febc1cfa400>),
#  (35679, 'As You Like It.txt', 721, <memory at 0x7febc1cfa4c0>),
#  (35680, 'As You Like It.txt', 722, <memory at 0x7febc1cfa580>),
#  (35681, 'As You Like It.txt', 723, <memory at 0x7febc1cfa640>),
#  (35682, 'As You Like It.txt', 724, <memory at 0x7febc1cfa700>),
#  (35683, 'As You Like It.txt', 725, <memory at 0x7febc1cfa7c0>),
#  (35684, 'As You Like It.txt', 726, <memory at 0x7febc1cfa880>),
#  (35685, 'As You Like It.txt', 727, <memory at 0x7febc1cfa940>),
#  (35686, 'As You Like It.txt', 728, <memory at 0x7febc1cfaa00>),
#  (35687, 'As You Like It.txt', 729, <memory at 0x7febc1cfaac0>),
#  (35688, 'As You Like It.txt', 730, <memory at 0x7febc1cfab80>),
#  (35689, 'As You Like It.txt', 731, <memory at 0x7febc1cfac40>),
#  (35690, 'As You Like It.txt', 732, <memory at 0x7febc1cfad00>),
#  (35691, 'As You Like It.txt', 733, <memory at 0x7febc1cfadc0>),
#  (35692, 'As You Like It.txt', 734, <memory at 0x7febc1cfae80>),
#  (35693, 'As You Like It.txt', 735, <memory at 0x7febc1cfaf40>),
#  (35694, 'As You Like It.txt', 736, <memory at 0x7febc1cfd040>),
#  (35695, 'As You Like It.txt', 737, <memory at 0x7febc1cfd100>),
#  (35696, 'As You Like It.txt', 738, <memory at 0x7febc1cfd1c0>),
#  (35697, 'As You Like It.txt', 739, <memory at 0x7febc1cfd280>),
#  (35698, 'As You Like It.txt', 740, <memory at 0x7febc1cfd340>),
#  (35699, 'As You Like It.txt', 741, <memory at 0x7febc1cfd400>),
#  (35700, 'As You Like It.txt', 742, <memory at 0x7febc1cfd4c0>),
#  (35701, 'As You Like It.txt', 743, <memory at 0x7febc1cfd580>),
#  (35702, 'As You Like It.txt', 744, <memory at 0x7febc1cfd640>),
#  (35703, 'As You Like It.txt', 745, <memory at 0x7febc1cfd700>),
#  (35704, 'As You Like It.txt', 746, <memory at 0x7febc1cfd7c0>),
#  (35705, 'As You Like It.txt', 747, <memory at 0x7febc1cfd880>),
#  (35706, 'As You Like It.txt', 748, <memory at 0x7febc1cfd940>),
#  (35707, 'As You Like It.txt', 749, <memory at 0x7febc1cfda00>),
#  (35708, 'As You Like It.txt', 750, <memory at 0x7febc1cfdac0>),
#  (35709, 'As You Like It.txt', 751, <memory at 0x7febc1cfdb80>),
#  (35718, 'As You Like It.txt', 760, <memory at 0x7febc1cfdc40>),
#  (35710, 'As You Like It.txt', 752, <memory at 0x7febc1cfdd00>),
#  (35711, 'As You Like It.txt', 753, <memory at 0x7febc1cfddc0>),
#  (35712, 'As You Like It.txt', 754, <memory at 0x7febc1cfde80>),
#  (35713, 'As You Like It.txt', 755, <memory at 0x7febc1cfdf40>),
#  (35737, 'As You Like It.txt', 779, <memory at 0x7febc1d01040>),
#  (35714, 'As You Like It.txt', 756, <memory at 0x7febc1d01100>),
#  (35715, 'As You Like It.txt', 757, <memory at 0x7febc1d011c0>),
#  (35716, 'As You Like It.txt', 758, <memory at 0x7febc1d01280>),
#  (35717, 'As You Like It.txt', 759, <memory at 0x7febc1d01340>),
#  (35719, 'As You Like It.txt', 761, <memory at 0x7febc1d01400>),
#  (35720, 'As You Like It.txt', 762, <memory at 0x7febc1d014c0>),
#  (35721, 'As You Like It.txt', 763, <memory at 0x7febc1d01580>),
#  (35722, 'As You Like It.txt', 764, <memory at 0x7febc1d01640>),
#  (35723, 'As You Like It.txt', 765, <memory at 0x7febc1d01700>),
#  (35724, 'As You Like It.txt', 766, <memory at 0x7febc1d017c0>),
#  (35725, 'As You Like It.txt', 767, <memory at 0x7febc1d01880>),
#  (35726, 'As You Like It.txt', 768, <memory at 0x7febc1d01940>),
#  (35727, 'As You Like It.txt', 769, <memory at 0x7febc1d01a00>),
#  (35728, 'As You Like It.txt', 770, <memory at 0x7febc1d01ac0>),
#  (35729, 'As You Like It.txt', 771, <memory at 0x7febc1d01b80>),
#  (35730, 'As You Like It.txt', 772, <memory at 0x7febc1d01c40>),
#  (35731, 'As You Like It.txt', 773, <memory at 0x7febc1d01d00>),
#  (35732, 'As You Like It.txt', 774, <memory at 0x7febc1d01dc0>),
#  (35733, 'As You Like It.txt', 775, <memory at 0x7febc1d01e80>),
#  (35734, 'As You Like It.txt', 776, <memory at 0x7febc1d01f40>),
#  (35735, 'As You Like It.txt', 777, <memory at 0x7febc1d03040>),
#  (35736, 'As You Like It.txt', 778, <memory at 0x7febc1d03100>),
#  (35738, 'As You Like It.txt', 780, <memory at 0x7febc1d031c0>),
#  (35739, 'As You Like It.txt', 781, <memory at 0x7febc1d03280>),
#  (35740, 'As You Like It.txt', 782, <memory at 0x7febc1d03340>),
#  (35741, 'As You Like It.txt', 783, <memory at 0x7febc1d03400>),
#  (35742, 'As You Like It.txt', 784, <memory at 0x7febc1d034c0>),
#  (35743, 'As You Like It.txt', 785, <memory at 0x7febc1d03580>),
#  (35744, 'As You Like It.txt', 786, <memory at 0x7febc1d03640>),
#  (35745, 'As You Like It.txt', 787, <memory at 0x7febc1d03700>),
#  (35746, 'As You Like It.txt', 788, <memory at 0x7febc1d037c0>),
#  (35747, 'As You Like It.txt', 789, <memory at 0x7febc1d03880>),
#  (35748, 'As You Like It.txt', 790, <memory at 0x7febc1d03940>),
#  (35749, 'As You Like It.txt', 791, <memory at 0x7febc1d03a00>),
#  (35750, 'As You Like It.txt', 792, <memory at 0x7febc1d03ac0>),
#  (35751, 'As You Like It.txt', 793, <memory at 0x7febc1d03b80>),
#  (35752, 'As You Like It.txt', 794, <memory at 0x7febc1d03c40>),
#  (35753, 'As You Like It.txt', 795, <memory at 0x7febc1d03d00>),
#  (35754, 'As You Like It.txt', 796, <memory at 0x7febc1d03dc0>),
#  (35755, 'As You Like It.txt', 797, <memory at 0x7febc1d03e80>),
#  (35756, 'As You Like It.txt', 798, <memory at 0x7febc1d03f40>),
#  (35757, 'As You Like It.txt', 799, <memory at 0x7febc1d07040>),
#  (35758, 'As You Like It.txt', 800, <memory at 0x7febc1d07100>),
#  (35759, 'As You Like It.txt', 801, <memory at 0x7febc1d071c0>),
#  (35760, 'As You Like It.txt', 802, <memory at 0x7febc1d07280>),
#  (35761, 'As You Like It.txt', 803, <memory at 0x7febc1d07340>),
#  (35762, 'As You Like It.txt', 804, <memory at 0x7febc1d07400>),
#  (35763, 'As You Like It.txt', 805, <memory at 0x7febc1d074c0>),
#  (35764, 'As You Like It.txt', 806, <memory at 0x7febc1d07580>),
#  (35765, 'As You Like It.txt', 807, <memory at 0x7febc1d07640>),
#  (35766, 'As You Like It.txt', 808, <memory at 0x7febc1d07700>),
#  (35767, 'As You Like It.txt', 809, <memory at 0x7febc1d077c0>),
#  (35768, 'As You Like It.txt', 810, <memory at 0x7febc1d07880>),
#  (35769, 'As You Like It.txt', 811, <memory at 0x7febc1d07940>),
#  (35770, 'As You Like It.txt', 812, <memory at 0x7febc1d07a00>),
#  (35771, 'As You Like It.txt', 813, <memory at 0x7febc1d07ac0>),
#  (35772, 'As You Like It.txt', 814, <memory at 0x7febc1d07b80>),
#  (35773, 'As You Like It.txt', 815, <memory at 0x7febc1d07c40>),
#  (35774, 'As You Like It.txt', 816, <memory at 0x7febc1d07d00>),
#  (35775, 'As You Like It.txt', 817, <memory at 0x7febc1d07dc0>),
#  (35776, 'As You Like It.txt', 818, <memory at 0x7febc1d07e80>),
#  (35777, 'As You Like It.txt', 819, <memory at 0x7febc1d07f40>),
#  (35778, 'As You Like It.txt', 820, <memory at 0x7febc1d0a040>),
#  (35779, 'As You Like It.txt', 821, <memory at 0x7febc1d0a100>),
#  (35780, 'As You Like It.txt', 822, <memory at 0x7febc1d0a1c0>),
#  (35781, 'As You Like It.txt', 823, <memory at 0x7febc1d0a280>),
#  (35782, 'As You Like It.txt', 824, <memory at 0x7febc1d0a340>),
#  (35783, 'As You Like It.txt', 825, <memory at 0x7febc1d0a400>),
#  (35784, 'As You Like It.txt', 826, <memory at 0x7febc1d0a4c0>),
#  (35785, 'As You Like It.txt', 827, <memory at 0x7febc1d0a580>),
#  (35786, 'As You Like It.txt', 828, <memory at 0x7febc1d0a640>),
#  (35787, 'As You Like It.txt', 829, <memory at 0x7febc1d0a700>),
#  (35788, 'As You Like It.txt', 830, <memory at 0x7febc1d0a7c0>),
#  (35789, 'As You Like It.txt', 831, <memory at 0x7febc1d0a880>),
#  (35790, 'As You Like It.txt', 832, <memory at 0x7febc1d0a940>),
#  (35791, 'As You Like It.txt', 833, <memory at 0x7febc1d0aa00>),
#  (35792, 'As You Like It.txt', 834, <memory at 0x7febc1d0aac0>),
#  (35793, 'As You Like It.txt', 835, <memory at 0x7febc1d0ab80>),
#  (35794, 'As You Like It.txt', 836, <memory at 0x7febc1d0ac40>),
#  (35795, 'As You Like It.txt', 837, <memory at 0x7febc1d0ad00>),
#  (35796, 'As You Like It.txt', 838, <memory at 0x7febc1d0adc0>),
#  (35797, 'As You Like It.txt', 839, <memory at 0x7febc1d0ae80>),
#  (35798, 'As You Like It.txt', 840, <memory at 0x7febc1d0af40>),
#  (35799, 'As You Like It.txt', 841, <memory at 0x7febc1d0c040>),
#  (35800, 'As You Like It.txt', 842, <memory at 0x7febc1d0c100>),
#  (35801, 'As You Like It.txt', 843, <memory at 0x7febc1d0c1c0>),
#  (35802, 'As You Like It.txt', 844, <memory at 0x7febc1d0c280>),
#  (35803, 'As You Like It.txt', 845, <memory at 0x7febc1d0c340>),
#  (35804, 'As You Like It.txt', 846, <memory at 0x7febc1d0c400>),
#  (35805, 'As You Like It.txt', 847, <memory at 0x7febc1d0c4c0>),
#  (35806, 'As You Like It.txt', 848, <memory at 0x7febc1d0c580>),
#  (35807, 'As You Like It.txt', 849, <memory at 0x7febc1d0c640>),
#  (35808, 'As You Like It.txt', 850, <memory at 0x7febc1d0c700>),
#  (35809, 'As You Like It.txt', 851, <memory at 0x7febc1d0c7c0>),
#  (35810, 'As You Like It.txt', 852, <memory at 0x7febc1d0c880>),
#  (35811, 'As You Like It.txt', 853, <memory at 0x7febc1d0c940>),
#  (35812, 'As You Like It.txt', 854, <memory at 0x7febc1d0ca00>),
#  (35813, 'As You Like It.txt', 855, <memory at 0x7febc1d0cac0>),
#  (35814, 'As You Like It.txt', 856, <memory at 0x7febc1d0cb80>),
#  (35815, 'As You Like It.txt', 857, <memory at 0x7febc1d0cc40>),
#  (35816, 'As You Like It.txt', 858, <memory at 0x7febc1d0cd00>),
#  (35817, 'As You Like It.txt', 859, <memory at 0x7febc1d0cdc0>),
#  (35818, 'As You Like It.txt', 860, <memory at 0x7febc1d0ce80>),
#  (35819, 'As You Like It.txt', 861, <memory at 0x7febc1d0cf40>),
#  (35820, 'As You Like It.txt', 862, <memory at 0x7febc1d0f040>),
#  (35821, 'As You Like It.txt', 863, <memory at 0x7febc1d0f100>),
#  (35822, 'As You Like It.txt', 864, <memory at 0x7febc1d0f1c0>),
#  (35823, 'As You Like It.txt', 865, <memory at 0x7febc1d0f280>),
#  (35824, 'As You Like It.txt', 866, <memory at 0x7febc1d0f340>),
#  (35825, 'As You Like It.txt', 867, <memory at 0x7febc1d0f400>),
#  (35826, 'As You Like It.txt', 868, <memory at 0x7febc1d0f4c0>),
#  (35827, 'As You Like It.txt', 869, <memory at 0x7febc1d0f580>),
#  (35828, 'As You Like It.txt', 870, <memory at 0x7febc1d0f640>),
#  (35829, 'As You Like It.txt', 871, <memory at 0x7febc1d0f700>),
#  (35830, 'As You Like It.txt', 872, <memory at 0x7febc1d0f7c0>),
#  (35831, 'As You Like It.txt', 873, <memory at 0x7febc1d0f880>),
#  (35832, 'As You Like It.txt', 874, <memory at 0x7febc1d0f940>),
#  (35833, 'As You Like It.txt', 875, <memory at 0x7febc1d0fa00>),
#  (35834, 'As You Like It.txt', 876, <memory at 0x7febc1d0fac0>),
#  (35835, 'As You Like It.txt', 877, <memory at 0x7febc1d0fb80>),
#  (35836, 'As You Like It.txt', 878, <memory at 0x7febc1d0fc40>),
#  (35837, 'As You Like It.txt', 879, <memory at 0x7febc1d0fd00>),
#  (35838, 'As You Like It.txt', 880, <memory at 0x7febc1d0fdc0>),
# ...
#  (35858, 'As You Like It.txt', 900, <memory at 0x7febc1d13d00>),
#  (35859, 'As You Like It.txt', 901, <memory at 0x7febc1d13dc0>),
#  (35860, 'As You Like It.txt', 902, <memory at 0x7febc1d13e80>),
#  (35861, 'As You Like It.txt', 903, <memory at 0x7febc1d13f40>),
#  (35862, 'As You Like It.txt', 904, <memory at 0x7febc1d16040>),
#  (35863, 'As You Like It.txt', 905, <memory at 0x7febc1d16100>),
#  (35864, 'As You Like It.txt', 906, <memory at 0x7febc1d161c0>),
#  (35865, 'As You Like It.txt', 907, <memory at 0x7febc1d16280>),
#  (35866, 'As You Like It.txt', 908, <memory at 0x7febc1d16340>),
#  (35867, 'As You Like It.txt', 909, <memory at 0x7febc1d16400>),
#  (35868, 'As You Like It.txt', 910, <memory at 0x7febc1d164c0>),
#  (35869, 'As You Like It.txt', 911, <memory at 0x7febc1d16580>),
#  (35870, 'As You Like It.txt', 912, <memory at 0x7febc1d16640>),
#  (35871, 'As You Like It.txt', 913, <memory at 0x7febc1d16700>),
#  (35872, 'As You Like It.txt', 914, <memory at 0x7febc1d167c0>),
#  (35873, 'As You Like It.txt', 915, <memory at 0x7febc1d16880>),
#  (35874, 'As You Like It.txt', 916, <memory at 0x7febc1d16940>),
#  (35875, 'As You Like It.txt', 917, <memory at 0x7febc1d16a00>),
#  (35876, 'As You Like It.txt', 918, <memory at 0x7febc1d16ac0>),
#  (35877, 'As You Like It.txt', 919, <memory at 0x7febc1d16b80>),
#  (35878, 'As You Like It.txt', 920, <memory at 0x7febc1d16c40>),
#  (35879, 'As You Like It.txt', 921, <memory at 0x7febc1d16d00>),
#  (35880, 'As You Like It.txt', 922, <memory at 0x7febc1d16dc0>),
#  (35881, 'As You Like It.txt', 923, <memory at 0x7febc1d16e80>),
#  (35882, 'As You Like It.txt', 924, <memory at 0x7febc1d16f40>),
#  (35883, 'As You Like It.txt', 925, <memory at 0x7febc1d19040>),
#  (35884, 'As You Like It.txt', 926, <memory at 0x7febc1d19100>),
#  (35885, 'As You Like It.txt', 927, <memory at 0x7febc1d191c0>),
#  (35886, 'As You Like It.txt', 928, <memory at 0x7febc1d19280>),
#  (35887, 'As You Like It.txt', 929, <memory at 0x7febc1d19340>),
#  (35888, 'As You Like It.txt', 930, <memory at 0x7febc1d19400>),
#  (35889, 'As You Like It.txt', 931, <memory at 0x7febc1d194c0>),
#  (35890, 'As You Like It.txt', 932, <memory at 0x7febc1d19580>),
#  (35891, 'As You Like It.txt', 933, <memory at 0x7febc1d19640>),
#  (35892, 'As You Like It.txt', 934, <memory at 0x7febc1d19700>),
#  (35893, 'As You Like It.txt', 935, <memory at 0x7febc1d197c0>),
#  (35894, 'As You Like It.txt', 936, <memory at 0x7febc1d19880>),
#  (35895, 'As You Like It.txt', 937, <memory at 0x7febc1d19940>),
#  (35896, 'As You Like It.txt', 938, <memory at 0x7febc1d19a00>),
#  (35897, 'As You Like It.txt', 939, <memory at 0x7febc1d19ac0>),
#  (35898, 'As You Like It.txt', 940, <memory at 0x7febc1d19b80>),
#  (35899, 'As You Like It.txt', 941, <memory at 0x7febc1d19c40>),
#  (35900, 'As You Like It.txt', 942, <memory at 0x7febc1d19d00>),
#  (35901, 'As You Like It.txt', 943, <memory at 0x7febc1d19dc0>),
#  (35902, 'As You Like It.txt', 944, <memory at 0x7febc1d19e80>),
#  (35903, 'As You Like It.txt', 945, <memory at 0x7febc1d19f40>),
#  (35904, 'As You Like It.txt', 946, <memory at 0x7febc1d1c040>),
#  (35905, 'As You Like It.txt', 947, <memory at 0x7febc1d1c100>),
#  (35906, 'As You Like It.txt', 948, <memory at 0x7febc1d1c1c0>),
#  (35907, 'As You Like It.txt', 949, <memory at 0x7febc1d1c280>),
#  (35908, 'As You Like It.txt', 950, <memory at 0x7febc1d1c340>),
#  (35909, 'As You Like It.txt', 951, <memory at 0x7febc1d1c400>),
#  (35910, 'As You Like It.txt', 952, <memory at 0x7febc1d1c4c0>),
#  (35911, 'As You Like It.txt', 953, <memory at 0x7febc1d1c580>),
#  (35912, 'As You Like It.txt', 954, <memory at 0x7febc1d1c640>),
#  (35913, 'As You Like It.txt', 955, <memory at 0x7febc1d1c700>),
#  (35914, 'As You Like It.txt', 956, <memory at 0x7febc1d1c7c0>),
#  (35915, 'As You Like It.txt', 957, <memory at 0x7febc1d1c880>),
#  (35916, 'As You Like It.txt', 958, <memory at 0x7febc1d1c940>),
#  (35917, 'As You Like It.txt', 959, <memory at 0x7febc1d1ca00>),
#  (35918, 'As You Like It.txt', 960, <memory at 0x7febc1d1cac0>),
#  (35919, 'As You Like It.txt', 961, <memory at 0x7febc1d1cb80>),
#  (35920, 'As You Like It.txt', 962, <memory at 0x7febc1d1cc40>),
#  (35921, 'As You Like It.txt', 963, <memory at 0x7febc1d1cd00>),
#  (35922, 'As You Like It.txt', 964, <memory at 0x7febc1d1cdc0>),
#  (35923, 'As You Like It.txt', 965, <memory at 0x7febc1d1ce80>),
#  (35924, 'As You Like It.txt', 966, <memory at 0x7febc1d1cf40>),
#  (35925, 'As You Like It.txt', 967, <memory at 0x7febc1d1f040>),
#  (35926, 'As You Like It.txt', 968, <memory at 0x7febc1d1f100>),
#  (35927, 'As You Like It.txt', 969, <memory at 0x7febc1d1f1c0>),
#  (35928, 'As You Like It.txt', 970, <memory at 0x7febc1d1f280>),
#  (35929, 'As You Like It.txt', 971, <memory at 0x7febc1d1f340>),
#  (35930, 'As You Like It.txt', 972, <memory at 0x7febc1d1f400>),
#  (35931, 'As You Like It.txt', 973, <memory at 0x7febc1d1f4c0>),
#  (35932, 'As You Like It.txt', 974, <memory at 0x7febc1d1f580>),
#  (35933, 'As You Like It.txt', 975, <memory at 0x7febc1d1f640>),
#  (35934, 'As You Like It.txt', 976, <memory at 0x7febc1d1f700>),
#  (35935, 'As You Like It.txt', 977, <memory at 0x7febc1d1f7c0>),
#  (35936, 'As You Like It.txt', 978, <memory at 0x7febc1d1f880>),
#  (35937, 'As You Like It.txt', 979, <memory at 0x7febc1d1f940>),
#  (35938, 'As You Like It.txt', 980, <memory at 0x7febc1d1fa00>),
#  (35939, 'As You Like It.txt', 981, <memory at 0x7febc1d1fac0>),
#  (35940, 'As You Like It.txt', 982, <memory at 0x7febc1d1fb80>),
#  (35941, 'As You Like It.txt', 983, <memory at 0x7febc1d1fc40>),
#  (35942, 'As You Like It.txt', 984, <memory at 0x7febc1d1fd00>),
#  (35943, 'As You Like It.txt', 985, <memory at 0x7febc1d1fdc0>),
#  (35944, 'As You Like It.txt', 986, <memory at 0x7febc1d1fe80>),
#  (35945, 'As You Like It.txt', 987, <memory at 0x7febc1d1ff40>),
#  (35946, 'As You Like It.txt', 988, <memory at 0x7febc1d21040>),
#  (35947, 'As You Like It.txt', 989, <memory at 0x7febc1d21100>),
#  (35948, 'As You Like It.txt', 990, <memory at 0x7febc1d211c0>),
#  (35949, 'As You Like It.txt', 991, <memory at 0x7febc1d21280>),
#  (35950, 'As You Like It.txt', 992, <memory at 0x7febc1d21340>),
#  (35951, 'As You Like It.txt', 993, <memory at 0x7febc1d21400>),
#  (35952, 'As You Like It.txt', 994, <memory at 0x7febc1d214c0>),
#  (35953, 'As You Like It.txt', 995, <memory at 0x7febc1d21580>),
#  (35954, 'As You Like It.txt', 996, <memory at 0x7febc1d21640>),
#  (35955, 'As You Like It.txt', 997, <memory at 0x7febc1d21700>),
#  (35956, 'As You Like It.txt', 998, <memory at 0x7febc1d217c0>),
#  (35957, 'As You Like It.txt', 999, <memory at 0x7febc1d21880>),
#  (35958, 'As You Like It.txt', 1000, <memory at 0x7febc1d21940>),
#  (35959, 'As You Like It.txt', 1001, <memory at 0x7febc1d21a00>),
#  (35960, 'As You Like It.txt', 1002, <memory at 0x7febc1d21ac0>),
#  (35961, 'As You Like It.txt', 1003, <memory at 0x7febc1d21b80>),
#  (35962, 'As You Like It.txt', 1004, <memory at 0x7febc1d21c40>),
#  (35963, 'As You Like It.txt', 1005, <memory at 0x7febc1d21d00>),
#  (35964, 'As You Like It.txt', 1006, <memory at 0x7febc1d21dc0>),
#  (35965, 'As You Like It.txt', 1007, <memory at 0x7febc1d21e80>),
#  (35966, 'As You Like It.txt', 1008, <memory at 0x7febc1d21f40>),
#  (35967, 'As You Like It.txt', 1009, <memory at 0x7febc1d25040>),
#  (35968, 'As You Like It.txt', 1010, <memory at 0x7febc1d25100>),
#  (35969, 'As You Like It.txt', 1011, <memory at 0x7febc1d251c0>),
#  (35970, 'As You Like It.txt', 1012, <memory at 0x7febc1d25280>),
#  (35971, 'As You Like It.txt', 1013, <memory at 0x7febc1d25340>),
#  (35972, 'As You Like It.txt', 1014, <memory at 0x7febc1d25400>),
#  (35973, 'As You Like It.txt', 1015, <memory at 0x7febc1d254c0>),
#  (35974, 'As You Like It.txt', 1016, <memory at 0x7febc1d25580>),
#  (35975, 'As You Like It.txt', 1017, <memory at 0x7febc1d25640>),
#  (35976, 'As You Like It.txt', 1018, <memory at 0x7febc1d25700>),
#  (35977, 'As You Like It.txt', 1019, <memory at 0x7febc1d257c0>),
#  (35978, 'As You Like It.txt', 1020, <memory at 0x7febc1d25880>),
#  (35979, 'As You Like It.txt', 1021, <memory at 0x7febc1d25940>),
#  (35980, 'As You Like It.txt', 1022, <memory at 0x7febc1d25a00>),
#  (35981, 'As You Like It.txt', 1023, <memory at 0x7febc1d25ac0>),
#  (35982, 'As You Like It.txt', 1024, <memory at 0x7febc1d25b80>),
#  (35983, 'As You Like It.txt', 1025, <memory at 0x7febc1d25c40>),
#  (35984, 'As You Like It.txt', 1026, <memory at 0x7febc1d25d00>),
#  (35985, 'As You Like It.txt', 1027, <memory at 0x7febc1d25dc0>),
#  (35986, 'As You Like It.txt', 1028, <memory at 0x7febc1d25e80>),
#  (35987, 'As You Like It.txt', 1029, <memory at 0x7febc1d25f40>),
#  (35988, 'As You Like It.txt', 1030, <memory at 0x7febc1d28040>),
#  (35989, 'As You Like It.txt', 1031, <memory at 0x7febc1d28100>),
#  (35990, 'As You Like It.txt', 1032, <memory at 0x7febc1d281c0>),
#  (35991, 'As You Like It.txt', 1033, <memory at 0x7febc1d28280>),
#  (35992, 'As You Like It.txt', 1034, <memory at 0x7febc1d28340>),
#  (35993, 'As You Like It.txt', 1035, <memory at 0x7febc1d28400>),
#  (35994, 'As You Like It.txt', 1036, <memory at 0x7febc1d284c0>),
#  (35995, 'As You Like It.txt', 1037, <memory at 0x7febc1d28580>),
#  (35996, 'As You Like It.txt', 1038, <memory at 0x7febc1d28640>),
#  (35997, 'As You Like It.txt', 1039, <memory at 0x7febc1d28700>),
#  (35998, 'As You Like It.txt', 1040, <memory at 0x7febc1d287c0>),
#  (35999, 'As You Like It.txt', 1041, <memory at 0x7febc1d28880>),
#  (36000, 'As You Like It.txt', 1042, <memory at 0x7febc1d28940>),
#  (36001, 'As You Like It.txt', 1043, <memory at 0x7febc1d28a00>),
#  (36002, 'As You Like It.txt', 1044, <memory at 0x7febc1d28ac0>),
#  (36003, 'As You Like It.txt', 1045, <memory at 0x7febc1d28b80>),
#  (36004, 'As You Like It.txt', 1046, <memory at 0x7febc1d28c40>),
#  (36005, 'As You Like It.txt', 1047, <memory at 0x7febc1d28d00>),
#  (36006, 'As You Like It.txt', 1048, <memory at 0x7febc1d28dc0>),
#  (36007, 'As You Like It.txt', 1049, <memory at 0x7febc1d28e80>),
#  (36008, 'As You Like It.txt', 1050, <memory at 0x7febc1d28f40>),
#  (36009, 'As You Like It.txt', 1051, <memory at 0x7febc1d2b040>),
#  (36010, 'As You Like It.txt', 1052, <memory at 0x7febc1d2b100>),
#  (36011, 'As You Like It.txt', 1053, <memory at 0x7febc1d2b1c0>),
#  (36012, 'As You Like It.txt', 1054, <memory at 0x7febc1d2b280>),
#  (36013, 'As You Like It.txt', 1055, <memory at 0x7febc1d2b340>),
#  (36014, 'As You Like It.txt', 1056, <memory at 0x7febc1d2b400>),
#  (36015, 'As You Like It.txt', 1057, <memory at 0x7febc1d2b4c0>),
#  (36016, 'As You Like It.txt', 1058, <memory at 0x7febc1d2b580>),
#  (36017, 'As You Like It.txt', 1059, <memory at 0x7febc1d2b640>),
#  (36018, 'As You Like It.txt', 1060, <memory at 0x7febc1d2b700>),
#  (36019, 'As You Like It.txt', 1061, <memory at 0x7febc1d2b7c0>),
#  (36020, 'As You Like It.txt', 1062, <memory at 0x7febc1d2b880>),
#  (36021, 'As You Like It.txt', 1063, <memory at 0x7febc1d2b940>),
#  (36022, 'As You Like It.txt', 1064, <memory at 0x7febc1d2ba00>),
#  (36023, 'As You Like It.txt', 1065, <memory at 0x7febc1d2bac0>),
#  (36024, 'As You Like It.txt', 1066, <memory at 0x7febc1d2bb80>),
#  (36025, 'As You Like It.txt', 1067, <memory at 0x7febc1d2bc40>),
#  (36026, 'As You Like It.txt', 1068, <memory at 0x7febc1d2bd00>),
#  (36027, 'As You Like It.txt', 1069, <memory at 0x7febc1d2bdc0>),
#  (36028, 'As You Like It.txt', 1070, <memory at 0x7febc1d2be80>),
#  (36029, 'As You Like It.txt', 1071, <memory at 0x7febc1d2bf40>),
#  (36030, 'As You Like It.txt', 1072, <memory at 0x7febc1d2e040>),
#  (36031, 'As You Like It.txt', 1073, <memory at 0x7febc1d2e100>),
#  (36032, 'As You Like It.txt', 1074, <memory at 0x7febc1d2e1c0>),
#  (36033, 'As You Like It.txt', 1075, <memory at 0x7febc1d2e280>),
#  (36034, 'As You Like It.txt', 1076, <memory at 0x7febc1d2e340>),
#  (36035, 'As You Like It.txt', 1077, <memory at 0x7febc1d2e400>),
#  (36036, 'As You Like It.txt', 1078, <memory at 0x7febc1d2e4c0>),
#  (36037, 'As You Like It.txt', 1079, <memory at 0x7febc1d2e580>),
#  (36038, 'As You Like It.txt', 1080, <memory at 0x7febc1d2e640>),
#  (36039, 'As You Like It.txt', 1081, <memory at 0x7febc1d2e700>),
#  (36040, 'As You Like It.txt', 1082, <memory at 0x7febc1d2e7c0>),
#  (36041, 'As You Like It.txt', 1083, <memory at 0x7febc1d2e880>),
#  (36042, 'As You Like It.txt', 1084, <memory at 0x7febc1d2e940>),
#  (36043, 'As You Like It.txt', 1085, <memory at 0x7febc1d2ea00>),
#  (36044, 'As You Like It.txt', 1086, <memory at 0x7febc1d2eac0>),
#  (36045, 'As You Like It.txt', 1087, <memory at 0x7febc1d2eb80>),
#  (36046, 'As You Like It.txt', 1088, <memory at 0x7febc1d2ec40>),
#  (36047, 'As You Like It.txt', 1089, <memory at 0x7febc1d2ed00>),
#  (36048, 'As You Like It.txt', 1090, <memory at 0x7febc1d2edc0>),
#  (36049, 'As You Like It.txt', 1091, <memory at 0x7febc1d2ee80>),
#  (36050, 'As You Like It.txt', 1092, <memory at 0x7febc1d2ef40>),
#  (36051, 'As You Like It.txt', 1093, <memory at 0x7febc1d32040>),
#  (36052, 'As You Like It.txt', 1094, <memory at 0x7febc1d32100>),
#  (36053, 'As You Like It.txt', 1095, <memory at 0x7febc1d321c0>),
#  (36054, 'As You Like It.txt', 1096, <memory at 0x7febc1d32280>),
#  (36055, 'As You Like It.txt', 1097, <memory at 0x7febc1d32340>),
#  (36056, 'As You Like It.txt', 1098, <memory at 0x7febc1d32400>),
#  (36057, 'As You Like It.txt', 1099, <memory at 0x7febc1d324c0>),
#  (36058, 'As You Like It.txt', 1100, <memory at 0x7febc1d32580>),
#  (36059, 'As You Like It.txt', 1101, <memory at 0x7febc1d32640>),
#  (36060, 'As You Like It.txt', 1102, <memory at 0x7febc1d32700>),
#  (36061, 'As You Like It.txt', 1103, <memory at 0x7febc1d327c0>),
#  (36062, 'As You Like It.txt', 1104, <memory at 0x7febc1d32880>),
#  (36063, 'As You Like It.txt', 1105, <memory at 0x7febc1d32940>),
#  (36064, 'As You Like It.txt', 1106, <memory at 0x7febc1d32a00>),
#  (36065, 'As You Like It.txt', 1107, <memory at 0x7febc1d32ac0>),
#  (36066, 'As You Like It.txt', 1108, <memory at 0x7febc1d32b80>),
#  (36067, 'As You Like It.txt', 1109, <memory at 0x7febc1d32c40>),
#  (36068, 'As You Like It.txt', 1110, <memory at 0x7febc1d32d00>),
#  (36069, 'As You Like It.txt', 1111, <memory at 0x7febc1d32dc0>),
#  (36070, 'As You Like It.txt', 1112, <memory at 0x7febc1d32e80>),
#  (36071, 'As You Like It.txt', 1113, <memory at 0x7febc1d32f40>),
#  (36072, 'As You Like It.txt', 1114, <memory at 0x7febc1d33040>),
#  (36073, 'As You Like It.txt', 1115, <memory at 0x7febc1d33100>),
#  (36074, 'As You Like It.txt', 1116, <memory at 0x7febc1d331c0>),
#  (36075, 'As You Like It.txt', 1117, <memory at 0x7febc1d33280>),
#  (36076, 'As You Like It.txt', 1118, <memory at 0x7febc1d33340>),
#  (36077, 'As You Like It.txt', 1119, <memory at 0x7febc1d33400>),
#  (36078, 'As You Like It.txt', 1120, <memory at 0x7febc1d334c0>),
#  (36079, 'As You Like It.txt', 1121, <memory at 0x7febc1d33580>),
#  (36080, 'As You Like It.txt', 1122, <memory at 0x7febc1d33640>),
#  (36081, 'As You Like It.txt', 1123, <memory at 0x7febc1d33700>),
#  (36082, 'As You Like It.txt', 1124, <memory at 0x7febc1d337c0>),
#  (36083, 'As You Like It.txt', 1125, <memory at 0x7febc1d33880>),
#  (36084, 'As You Like It.txt', 1126, <memory at 0x7febc1d33940>),
#  (36085, 'As You Like It.txt', 1127, <memory at 0x7febc1d33a00>),
#  (36086, 'As You Like It.txt', 1128, <memory at 0x7febc1d33ac0>),
#  (36087, 'As You Like It.txt', 1129, <memory at 0x7febc1d33b80>),
#  (36088, 'As You Like It.txt', 1130, <memory at 0x7febc1d33c40>),
#  (36089, 'As You Like It.txt', 1131, <memory at 0x7febc1d33d00>),
#  (36090, 'As You Like It.txt', 1132, <memory at 0x7febc1d33dc0>),
#  (36091, 'As You Like It.txt', 1133, <memory at 0x7febc1d33e80>),
#  (36092, 'As You Like It.txt', 1134, <memory at 0x7febc1d33f40>),
#  (36093, 'As You Like It.txt', 1135, <memory at 0x7febc1d37040>),
#  (36094, 'As You Like It.txt', 1136, <memory at 0x7febc1d37100>),
#  (36095, 'As You Like It.txt', 1137, <memory at 0x7febc1d371c0>),
#  (36096, 'As You Like It.txt', 1138, <memory at 0x7febc1d37280>),
#  (36097, 'As You Like It.txt', 1139, <memory at 0x7febc1d37340>),
#  (36098, 'As You Like It.txt', 1140, <memory at 0x7febc1d37400>),
#  (36099, 'As You Like It.txt', 1141, <memory at 0x7febc1d374c0>),
#  (36100, 'As You Like It.txt', 1142, <memory at 0x7febc1d37580>),
#  ...]

# %%
import faiss

# %% [markdown]
# Now set the data structure up to use Faiss

# %%
key =[]
value = []
items = len(embeddings)
key_value = [[0 for x in range(3)] for y in range(items)] 

count = 0

#count and for is bad... but clear 
for D in embeddings:
    key=D[0] # should be the id field from postgress - should be unique and key
    value = bytes(D[3]) # D[3] should be the embedding as a bytea created by pickle.dump 
    key_value[count][0]=key
    key_value[count][1]=pickle.loads(bytes(value)) #unpickle the value from D[3] - tell python it's bytes. 
    count=count+1

# %%
import numpy
arr = numpy.array(key_value)
embeddings = numpy.array([embedding for embedding in arr[:,1]]).astype("float32")
# Out:
# <ipython-input-5-c7aa6be75df2>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = numpy.array(key_value)

# %%
#idds= numpy.arange(any, len(arr[:,0]), dtype="int64")#.astype('int64')
idds=arr[:,0]
idds = idds.copy(order='C').astype('int64')

# %%
embeddings
# Out:
# array([[ 0.08040225,  0.12598377,  0.09745149, ...,  0.05144682,
#         -0.0146205 , -0.01885655],
#        [-0.00612251,  0.04832892,  0.08627935, ..., -0.03951882,
#         -0.05325108,  0.05043194],
#        [-0.01785206,  0.00076679,  0.10930776, ...,  0.0833272 ,
#          0.03059571, -0.00564204],
#        ...,
#        [ 0.01452838,  0.07053237, -0.03795956, ..., -0.02179181,
#          0.05286616, -0.04377155],
#        [-0.04220096,  0.05377195,  0.06067434, ...,  0.04563998,
#          0.05898713, -0.01594879],
#        [ 0.04360894,  0.04844649, -0.01587826, ..., -0.00419272,
#          0.05998175,  0.02838317]], dtype=float32)

# %% [markdown]
# So - now create an index that can be used to find nearest neighbours according to the language model

# %%
#embeddings = np.array([embedding for embedding in key_value[1]]).astype("float32")
labels =arr[:,0].copy(order='C')
# Step 2: Instantiate the index
index = faiss.IndexFlatL2(embeddings.shape[1])

# Step 3: Pass the index to IndexIDMap
index = faiss.IndexIDMap(index)

# Step 4: Add vectors and their IDs
index.add_with_ids(embeddings, idds)

# %% [markdown]
# The cell below queries for the nearest neighbours of an arbitary embedding

# %% [markdown]
# Pretty print the results of a query

# %%
D, I = index.search(numpy.array([embeddings[4019]]), k=10)
conn = psycopg2.connect("dbname=postgres user=postgres password=postgres")
cur = conn.cursor()
neighbours = I[0]
for neighbour in neighbours :
    cur.execute('SELECT book,line,snippit from embeddings where embeddings.id=%s',(str(neighbour),))
    refs  = cur.fetchall()
    print (refs[0][0], "\t", refs[0][1], "\t",refs[0][2],"\n")
# Out:
# Cymbeline.txt 	 844 	      I'll make't my comfort
#      He is a man; I'll love him as my brother:
#      And such a welcome as I'd give to him
#      After long absence, such is yours: most welcome!
#
# Measure for Measure.txt 	 1256 	      Than that which lives to fear: make it your comfort,
#      So happy is your brother.
#
# Measure for Measure.txt 	 157 	      Gentle and fair, your brother kindly greets you:
#      Not to be weary with you, he's in prison.
#
# Two Gentlemen of Verona.txt 	 411 	      Confirm his welcome with some special favour.
#
# Richard III.txt 	 184 	      The heavens have bless'd you with a goodly son,
#      To be your comforter when he is gone.
#
# Henry VIII.txt 	 377 	      And once more in mine arms I bid him welcome,
#      And thank the holy conclave for their loves:
#      They have sent me such a man I would have wish'd for.
#
# Richard III.txt 	 1001 	      You shall have letters from me to my son
#      To meet you on the way, and welcome you.
#
# Titus Andronicus.txt 	 432 	      And, for our father's sake and mother's care,
#      Now let me show a brother's love to thee.
#
# Henry IV, part 2.txt 	 1385 	      grieve at this; I shall be sent for in private to
#      him: look you, he must seem thus to the world:
#      fear not your advancements; I will be the man yet
#      that shall make you great.
#
# Henry VI, part 1.txt 	 952 	      Thanks, Reignier, happy for so sweet a child,
#      Fit to be made companion with a king:
#      What answer makes your grace unto my suit?

# %%
D
# Out:
# array([[0.        , 0.7646222 , 0.77018774, 0.84607553, 0.84947324,
#         0.86867416, 0.88350713, 0.88385713, 0.88795406, 0.89648974]],
#       dtype=float32)

# %%
import networkx as nx
G = nx.Graph()
conn = psycopg2.connect("dbname=postgres user=postgres password=postgres")
cur = conn.cursor()
for line in embeddings :
    D, I = index.search(numpy.array([line]), k=5)
    cur.execute('SELECT book,line,snippit from embeddings where embeddings.id=%s',(str(I[0][0]),))
    origin  = cur.fetchall()[0][0]
    for edge in I[0]:
        cur.execute('SELECT book,line,snippit from embeddings where embeddings.id=%s',(str(edge),))
        connection  = cur.fetchall()[0][0]
        G.add_edge(origin,connection) #adds an edge to itself, which might need to be removed.

# %%
import matplotlib.pyplot as plt

# %%
nx.write_graphml(G, "shakespeare-graph.graphml")

# %%
#nx.draw_networkx(G)
plt.figure(3,figsize=(12,12)) 
nx.draw_networkx(G)
plt.show()

# %%
conn = psycopg2.connect("dbname=postgres user=postgres password=postgres")
cur = conn.cursor()
#get the list of books 
cur.execute('SELECT book from embeddings where embeddings.author=%s group by book',("Shakespear",))
books = cur.fetchall()
newbooks = []
for book in books:
    newbooks.append(book[0])
    

#create reusts array   
links_clean = np.zeros([len(newbooks),len(newbooks)])
for line in embeddings :
    D, I = index.search(numpy.array([line]), k=5)
    cur.execute('SELECT book,line,snippit from embeddings where embeddings.id=%s',(str(I[0][0]),))
    origin  = cur.fetchall()[0][0]
    origin_pos = newbooks.index(origin)
  
    for edge in I[0]:
        count = 1
        cur.execute('SELECT book,line,snippit from embeddings where embeddings.id=%s',(str(edge),))
        connection  = cur.fetchall()[0][0]
        connection_pos = newbooks.index(connection)
        if (connection_pos!=origin_pos):
            current_val = links[origin_pos][connection_pos]
            delta = 1.0 - D[0][count] #is this embedding considered "close" by faiss?
            if delta > 0.90 :
                links_clean[origin_pos][connection_pos] =links_clean[origin_pos][connection_pos]+ delta
            count=count+1

# %%
plt.figure(3,figsize=(12,12)) 
uniform_data = np.random.rand(10, 12)
x_axis_labels = books
y_axis_labels = books
sorted=np.argsort(links_clean)
ax = sns.heatmap(links_clean, linewidth=0.5,xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.show()

# %%
summed=np.sum(links_clean,axis=1).tolist()

# %%
import pandas as pd
df = pd.DataFrame({'Books':books, 'summed':summed})
df.sort_values('summed')
# Out:
#                                Books      summed
# 17           (Comedy of Errors.txt,)   23.813960
# 34           (Titus Andronicus.txt,)   39.000000
# 31       (Love's Labour's Lost.txt,)   42.000000
# 23            (Timon of Athens.txt,)   58.000000
# 8     (Midsummer Night's Dream.txt,)   64.000000
# 7                  (Richard II.txt,)   65.000000
# 24         (Merchant of Venice.txt,)   73.000000
# 20                  (King John.txt,)   75.000000
# 32           (Henry VI, part 3.txt,)   83.000000
# 30           (Romeo and Juliet.txt,)   84.000000
# 27                 (Henry VIII.txt,)   96.000000
# 28                (Richard III.txt,)  101.000000
# 21           (Henry VI, part 1.txt,)  102.000000
# 19              (Twelfth Night.txt,)  103.000000
# 11                    (Macbeth.txt,)  109.979090
# 15        (Taming of the Shrew.txt,)  110.000000
# 16     (Much Ado About Nothing.txt,)  117.000000
# 5                     (Henry V.txt,)  128.000000
# 1      (Merry Wives of Windsor.txt,)  144.000000
# 22                     (Hamlet.txt,)  154.806503
# 9                    (Pericles.txt,)  155.000000
# 2         (Measure for Measure.txt,)  167.618176
# 12           (Henry IV, part 1.txt,)  168.000000
# 33       (Troiles and Cressida.txt,)  180.000000
# 29           (Henry VI, part 2.txt,)  185.000000
# 0     (Two Gentlemen of Verona.txt,)  205.000000
# 25           (Henry IV, part 2.txt,)  206.838133
# 10       (Antony and Cleopatra.txt,)  210.720249
# 6                 (The Tempest.txt,)  219.000000
# 13                  (King Lear.txt,)  252.620462
# 35  (All's Well That Ends Well.txt,)  262.000000
# 26                    (Othello.txt,)  291.000000
# 18                  (Cymbeline.txt,)  333.688050
# 14                 (Coriolanus.txt,)  423.929824
# 4               (Julius Caesar.txt,)  636.821289
# 3              (As You Like It.txt,)  859.000000

# %%
df
# Out:
#                                Books  summed
# 0     (Two Gentlemen of Verona.txt,)  3321.0
# 1      (Merry Wives of Windsor.txt,)  4075.0
# 2         (Measure for Measure.txt,)  3997.0
# 3              (As You Like It.txt,)  4210.0
# 4               (Julius Caesar.txt,)  3530.0
# 5                 (The Tempest.txt,)  3266.0
# 6                     (Henry V.txt,)  3603.0
# 7                  (Richard II.txt,)  3061.0
# 8     (Midsummer Night's Dream.txt,)  2316.0
# 9                    (Pericles.txt,)  3277.0
# 10       (Antony and Cleopatra.txt,)  4568.0
# 11                    (Macbeth.txt,)  3114.0
# 12           (Henry IV, part 1.txt,)  3976.0
# 13                  (King Lear.txt,)  5183.0
# 14                 (Coriolanus.txt,)  4858.0
# 15        (Taming of the Shrew.txt,)  3423.0
# 16     (Much Ado About Nothing.txt,)  4134.0
# 17           (Comedy of Errors.txt,)  2111.0
# 18                  (Cymbeline.txt,)  5043.0
# 19              (Twelfth Night.txt,)  3888.0
# 20                  (King John.txt,)  2969.0
# 21           (Henry VI, part 1.txt,)  3178.0
# 22                     (Hamlet.txt,)  5102.0
# 23            (Timon of Athens.txt,)  3387.0
# 24         (Merchant of Venice.txt,)  3016.0
# 25           (Henry IV, part 2.txt,)  4585.0
# 26                    (Othello.txt,)  4953.0
# 27                 (Henry VIII.txt,)  3901.0
# 28                (Richard III.txt,)  4741.0
# 29           (Henry VI, part 2.txt,)  4150.0
# 30           (Romeo and Juliet.txt,)  3664.0
# 31       (Love's Labour's Lost.txt,)  4084.0
# 32           (Henry VI, part 3.txt,)  3525.0
# 33       (Troiles and Cressida.txt,)  4225.0
# 34           (Titus Andronicus.txt,)  2519.0
# 35  (All's Well That Ends Well.txt,)  4369.0

# %%
import math
links_log = np.zeros([len(newbooks),len(newbooks)])
for a in range(0,len(newbooks)):
    for b in range (0,len(newbooks)):
        links_log[a][b] = math.log(links_clean[a][b]+0.000000000000001)
plt.figure(3,figsize=(12,12)) 
x_axis_labels = books
y_axis_labels = books
ax = sns.heatmap(links_log, linewidth=0.5,xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.show()
